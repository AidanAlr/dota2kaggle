# %%
import warnings
from typing import Any

from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.model_selection import HalvingGridSearchCV, RandomizedSearchCV  # noqa
from sklearn.model_selection import train_test_split
from dataclasses import dataclass
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, RobustScaler, MinMaxScaler
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.base import clone
import numpy as np


warnings.filterwarnings('ignore')

# %%
train_data = pd.read_csv('train_data.CSV')
test_data = pd.read_csv('test_data.CSV')

# %%
player_numbers = ['1', '2', '3', '4', '5']

# %%
def get_hero_win_rates(df):
    # Create empty list to store all hero-game combinations
    hero_games = []

    # Process Radiant players (r1-r5)
    for i in player_numbers:
        radiant_col = f'r{i}_hero_id'
        if radiant_col in df.columns:
            # For radiant players, they win when radiant_win == 1
            radiant_data = df[[radiant_col, 'radiant_win']].copy()
            radiant_data.columns = ['hero_id', 'won']
            radiant_data = radiant_data.dropna(subset=['hero_id']) 
            hero_games.append(radiant_data)

    # Process Dire players (d1-d5)
    for i in player_numbers:
        dire_col = f'd{i}_hero_id'
        if dire_col in df.columns:
            # For dire players, they win when radiant_win == 0
            dire_data = df[[dire_col, 'radiant_win']].copy()
            dire_data.columns = ['hero_id', 'won']
            dire_data['won'] = 1 - dire_data['won']  # Flip for dire side
            dire_data = dire_data.dropna(subset=['hero_id']) 
            hero_games.append(dire_data)

    # Combine all hero games
    all_hero_games = pd.concat(hero_games, ignore_index=True)

    # Calculate win rates
    win_rates = all_hero_games.groupby('hero_id').agg({
        'won': ['sum', 'count']
    }).round(4)

    win_rates.columns = ['wins', 'total_games']
    win_rates['win_rate'] = (win_rates['wins'] / win_rates['total_games']).round(4)

    return win_rates.sort_values('win_rate', ascending=False)

# %%
for df in [train_data, test_data]:
    df.drop(columns=['chat_len'], inplace=True)
    df['radiant_carry_%_team_gold'] = df['r1_gold'] / (df['r1_gold'] + df['r2_gold'] + df['r3_gold'] + df['r4_gold'] + df['r5_gold'])
    df['radiant_carry_%_total_gold'] = df['r1_gold'] / (
            df['r1_gold'] + df['r2_gold'] + df['r3_gold'] + df['r4_gold'] + df['r5_gold'] + df['d1_gold'] + df['d2_gold'] + df[
        'd3_gold'] + df['d4_gold'] + df['d5_gold'])

    # Team Stats
    for stat in ['gold', 'xp']:
        dire_team_stat = df[[f'd{number}_{stat}' for number in player_numbers]].sum(axis=1)
        df[f'radiant_team_{stat}'] = df[[f'r{number}_{stat}' for number in player_numbers]].sum(axis=1)
        df[f'radiant_team_{stat}_lead'] = dire_team_stat - df[f'radiant_team_{stat}']
        df[f'radiant_carries_{stat}_lead'] = df[f'r1_{stat}'] - df[f'd1_{stat}'] + df[f'r2_{stat}'] - df[f'd2_{stat}']

# %%
# Calculate win rates from training data only
hero_win_rates = get_hero_win_rates(train_data)
hero_winrate_dict = hero_win_rates['win_rate'].to_dict()
overall_avg_winrate = hero_win_rates['win_rate'].mean()

# Rest of your code with one key change - handle missing heroes:
radiant_players = ['r1', 'r2', 'r3', 'r4', 'r5']
dire_players = ['d1', 'd2', 'd3', 'd4', 'd5']
player_stats = ['kills', 'deaths', 'assists', 'denies', 'gold', 'lh', 'xp', 'health', 'max_health', 'max_mana', 'level', 'stuns',
                'creeps_stacked', 'camps_stacked', 'rune_pickups', 'firstblood_claimed', 'teamfight_participation', 'towers_killed',
                'roshans_killed', 'obs_placed', 'sen_placed']


def process_hero_stats(df):
    for radiant, dire in zip(radiant_players, dire_players):
        # Get rid of the coordinates x,y
        df = df.drop([f'{radiant}_x', f'{radiant}_y', f'{dire}_x', f'{dire}_y'], axis=1)
        # Map win rates with fallback to average for unknown heroes
        df[f'{radiant}_hero_winrate'] = df[f'{radiant}_hero_id'].map(hero_winrate_dict).fillna(overall_avg_winrate)
        df[f'{dire}_hero_winrate'] = df[f'{dire}_hero_id'].map(hero_winrate_dict).fillna(overall_avg_winrate)
        df = df.drop([f'{radiant}_hero_id', f'{dire}_hero_id'], axis=1)
        for stat in player_stats:
            # Get the radiant lead for the stat
            df[f'{radiant}_{stat}_lead'] = df[f'{radiant}_{stat}'] - df[f'{dire}_{stat}']
            # Drop the individual player stats
            df = df.drop([f'{radiant}_{stat}', f'{dire}_{stat}'], axis=1)

    return df

# %%
train_data = process_hero_stats(train_data)
test_data = process_hero_stats(test_data)

# %%
test_data
# Out:
#       game_time  game_mode  lobby_type  objectives_len  \
# 0           155         22           7               1
# 1          1362          4           0               6
# 2          2388          4           0              16
# 3          2043         22           0              15
# 4           840         22           7               2
# ...         ...        ...         ...             ...
# 9995       2525         22           0              15
# 9996       1002          4           0               4
# 9997        643         22           7               1
# 9998       2405         22           7              12
# 9999       1775         22           0              10
#
#                                     ID  radiant_carry_%_team_gold  \
# 0     a400b8f29dece5f4d266f49f1ae2e98a                   0.266568
# 1     34c81a8faede0d8f1f87dcc6ee824658                   0.221980
# 2     5feece770ca79e5e8cd8052198b3f533                   0.208383
# 3     8f56cc2468ba5c37edb79f3a7b4af6e6                   0.228447
# 4     44cdded6d3311134563f743eb77685b2                   0.187484
# ...                                ...                        ...
# 9995  308faee28efee2e66b39f9f2ba6ea9cf                   0.161932
# 9996  6066cc7417b43c749d551e123d00f0c8                   0.212522
# 9997  e2ca68ac1a6847f4a37f6c9c8ee8695b                   0.153894
# 9998  47ad6454ede66c1c78fdaa9391dfc556                   0.161861
# 9999  9928dfde50efcbdb2055da23dcdbc101                   0.147871
#
#       radiant_carry_%_total_gold  radiant_team_gold  radiant_team_gold_lead  \
# 0                       0.090727               2037                    1911
# 1                       0.105656              38098                    3847
# 2                       0.108253              87320                   -6553
# 3                       0.094634              53229                   22037
# 4                       0.090807              19015                    1229
# ...                          ...                ...                     ...
# 9995                    0.087170              85925                  -12231
# 9996                    0.096385              21706                    4448
# 9997                    0.060538              11352                    6154
# 9998                    0.084374              88811                   -7250
# 9999                    0.075860              59829                   -3035
#
#       radiant_carries_gold_lead  ...  r5_stuns_lead  r5_creeps_stacked_lead  \
# 0                          -828  ...       0.000000                       0
# 1                            98  ...     -10.064224                      -9
# 2                         -5909  ...       0.110524                       2
# 3                         -9972  ...     -39.865319                       0
# 4                          -431  ...       0.000000                       0
# ...                         ...  ...            ...                     ...
# 9995                      -6012  ...       0.000000                      -6
# 9996                      -1330  ...      12.596962                       0
# 9997                      -2278  ...       2.532715                       0
# 9998                      -4096  ...      17.480328                      -3
# 9999                        818  ...       6.441088                       2
#
#       r5_camps_stacked_lead  r5_rune_pickups_lead  r5_firstblood_claimed_lead  \
# 0                         0                     0                           0
# 1                        -3                   -12                           0
# 2                         1                    12                           0
# 3                         0                     7                           0
# 4                         0                    -1                           0
# ...                     ...                   ...                         ...
# 9995                     -2                    13                           0
# 9996                      0                   -10                          -1
# 9997                      0                    -3                          -1
# 9998                     -1                     6                           0
# 9999                      1                     1                           0
#
#       r5_teamfight_participation_lead  r5_towers_killed_lead  \
# 0                            0.000000                      0
# 1                            0.420635                      0
# 2                           -0.149689                      1
# 3                           -0.445946                     -2
# 4                           -0.017857                     -1
# ...                               ...                    ...
# 9995                         0.107212                      0
# 9996                         0.158730                      0
# 9997                        -0.500000                      0
# 9998                         0.041667                      3
# 9999                         0.116667                     -1
#
#       r5_roshans_killed_lead  r5_obs_placed_lead  r5_sen_placed_lead
# 0                          0                   0                   0
# 1                          0                   0                   0
# 2                          0                   0                   0
# 3                          0                   4                   0
# 4                          0                   0                   0
# ...                      ...                 ...                 ...
# 9995                       0                   0                  11
# 9996                       0                   0                   0
# 9997                       0                   0                   1
# 9998                       1                   0                   0
# 9999                       0                   8                   4
#
# [10000 rows x 128 columns]

# %%
train_data
# Out:
#        game_time  game_mode  lobby_type  objectives_len  radiant_win  \
# 0            871         22           0               4         True
# 1           2549         22           0              17         True
# 2           1841         22           0               8         True
# 3           2211         22           7              11         True
# 4            458         22           7               1         True
# ...          ...        ...         ...             ...          ...
# 29670       1664          3           0               8        False
# 29671       2898         22           7              26         True
# 29672       1246         23           0               6         True
# 29673       2620         22           7              15        False
# 29674       1111         22           7               5         True
#
#                                      ID  radiant_carry_%_team_gold  \
# 0      a363534a6344f1b0be1d7ba2c4047d9a                   0.124252
# 1      a0ba4ef0965f56d2eba69c2b9ef33353                   0.317245
# 2      18873e56c2142af326b4e08ca41df63a                   0.157368
# 3      c143931a6a8b3fb55a8ef6b9f30c6933                   0.253589
# 4      5a324d8b37522e9f9684493465720023                   0.296747
# ...                                 ...                        ...
# 29670  db7050396622d08c6e8a5d6aeedf5f44                   0.235066
# 29671  b1259dbd78c0e36cba45c2f567c9d3de                   0.207528
# 29672  9bae67d14d950856a9693b7efd9bce3f                   0.216844
# 29673  de2e339479cf8e5697aff693d190e411                   0.284716
# 29674  4700d6bb41fc91f3400a68d48bfdc3d1                   0.139250
#
#        radiant_carry_%_total_gold  radiant_team_gold  radiant_team_gold_lead  \
# 0                        0.073763              26575                   -8385
# 1                        0.168983              89590                  -10986
# 2                        0.077559              57769                    1676
# 3                        0.138347              72720                  -12145
# 4                        0.154515               9284                    -738
# ...                           ...                ...                     ...
# 29670                    0.101131              45451                   14743
# 29671                    0.111176             118485                  -15799
# 29672                    0.109415              79458                   -1442
# 29673                    0.137672              96496                    6570
# 29674                    0.070171              28675                    -446
#
#        ...  r5_stuns_lead  r5_creeps_stacked_lead  r5_camps_stacked_lead  \
# 0      ...     -17.662320                       0                      0
# 1      ...     -33.003062                       0                      0
# 2      ...      -3.932761                       3                      1
# 3      ...      11.344666                       2                      1
# 4      ...       0.000000                       0                      0
# ...    ...            ...                     ...                    ...
# 29670  ...      30.359493                      10                      3
# 29671  ...     -34.718493                       0                      0
# 29672  ...      -3.298476                       0                      0
# 29673  ...      33.677744                       2                      1
# 29674  ...     -28.958778                     -11                     -4
#
#        r5_rune_pickups_lead  r5_firstblood_claimed_lead  \
# 0                        -7                          -1
# 1                         6                           0
# 2                        -2                           0
# 3                         2                           0
# 4                        -2                           0
# ...                     ...                         ...
# 29670                    -1                           0
# 29671                     4                           0
# 29672                     1                           0
# 29673                    -4                           0
# 29674                   -13                           0
#
#        r5_teamfight_participation_lead  r5_towers_killed_lead  \
# 0                            -0.602273                      0
# 1                            -0.123950                     -1
# 2                            -0.318182                      0
# 3                            -0.014493                      1
# 4                             0.166667                      0
# ...                                ...                    ...
# 29670                         0.053030                     -1
# 29671                         0.157956                      4
# 29672                         0.048148                      1
# 29673                        -0.125315                     -1
# 29674                         0.111111                      0
#
#        r5_roshans_killed_lead  r5_obs_placed_lead  r5_sen_placed_lead
# 0                           0                  -6                  -2
# 1                           0                  12                   5
# 2                           0                   0                   0
# 3                           0                   0                   2
# 4                           0                  -1                  -1
# ...                       ...                 ...                 ...
# 29670                       0                   1                   0
# 29671                       1                   0                   0
# 29672                       0                   0                   0
# 29673                       0                   1                   1
# 29674                       0                   2                  -1
#
# [29675 rows x 129 columns]

# %%
X_train, X_val = train_test_split(train_data, test_size=0.2)

y_train = X_train['radiant_win']
X_train = X_train.drop(['radiant_win', 'ID'], axis=1)

y_val = X_val['radiant_win']
X_val = X_val.drop(['radiant_win', 'ID'], axis=1)

X_test = test_data.drop('ID', axis=1)

# %%
def to_numpy(data) -> np.ndarray:
    """Convert data to numpy array"""
    if hasattr(data, 'values'):
        return data.values
    return np.array(data) if not isinstance(data, np.ndarray) else data


def validate_feature_names(feature_names, n_features: int) -> np.ndarray:
    """Validate and convert feature names"""
    if feature_names is None:
        return np.array([f'feature_{i}' for i in range(n_features)])

    if hasattr(feature_names, 'values'):
        return feature_names.values
    elif hasattr(feature_names, '__iter__') and not isinstance(feature_names, str):
        return np.array(list(feature_names))
    else:
        return np.array(feature_names)


def validate_inputs_cv(X_train, y_train, X_test) -> tuple[np.ndarray, ...]:
    """Validate and convert inputs to consistent format for CV approach"""
    # Validate feature names
    feature_names = validate_feature_names(X_train.columns, X_train.shape[1])

    # Convert to numpy arrays
    X_train = to_numpy(X_train)
    X_test = to_numpy(X_test)
    y_train = to_numpy(y_train).ravel()

    # Basic validation
    assert X_train.shape[1] == X_test.shape[1], "Feature dimension mismatch"
    assert len(feature_names) == X_train.shape[1], "Feature names length mismatch"

    return X_train, y_train, X_test, feature_names

# %%
@dataclass
class FeatureSelectionResult:
    best_scaler_name: str
    best_scaler: Any
    final_model: RandomForestClassifier | LogisticRegression
    feature_names: np.ndarray
    val_roc_auc: float
    best_model_cv_score: float
    best_n_features: int
    best_params: dict
    test_predictions: np.ndarray


@dataclass
class Config:
    scalers: dict[str, Any]
    models_and_param_grid: list[tuple[Any]]
    cv_folds: int = 3
    n_jobs: int = -1
    random_state: int = 42


@dataclass
class ModelScalerEvaluationResult:
    estimator_name: str
    scaler_name: str
    scaler: Any
    best_n_features: int
    best_result: dict
    scaled_data: tuple[np.ndarray, np.ndarray, np.ndarray]

# %%
def create_default_config(cv_folds: int = 3, n_jobs: int = -1, random_state: int = 42) -> Config:
    """Create default configuration for feature selection"""
    scalers = {
        'RobustScaler': RobustScaler(),
        'MinMaxScaler': MinMaxScaler(),
        'StandardScaler': StandardScaler(),
    }

    # rf_param_grid = {
    #     'max_depth': [10, 15, 20],
    #     'max_features': ['sqrt', 0.5],
    #     'min_samples_split': [5, 10],
    #     'min_samples_leaf': [2, 5],
    #     'class_weight': ['balanced', 'balanced_subsample'],
    # }
    # 
    # Logistic Regression Param Grid
    lr_param_grid = {
        'C': [0.1, 1, 10, 100],
        'penalty': ['l2', 'l1'], 
        'solver': ['liblinear', 'saga', 'sag', 'newton-cg'],  
        'max_iter': [1000],
        'class_weight': [None, 'balanced']
    }

    # Test each scaler
    # rf = RandomForestClassifier()
    lr = LogisticRegression()

    models_and_param_grid = [
        # (rf, rf_param_grid),
        (lr, lr_param_grid)
    ]
    return Config(
        models_and_param_grid=models_and_param_grid,
        scalers=scalers,
        cv_folds=cv_folds,
        n_jobs=n_jobs,
        random_state=random_state
    )

# %%
def apply_scaling(scaler, X_train: np.ndarray, X_val: np.ndarray, X_test: np.ndarray) -> tuple[
    np.ndarray, np.ndarray, np.ndarray]:
    """Apply scaling transformation"""
    if scaler is None:
        return X_train.copy(), X_val.copy(), X_test.copy()

    X_train_scaled = scaler.fit_transform(X_train)
    X_val_scaled = scaler.transform(X_val)
    X_test_scaled = scaler.transform(X_test)

    return X_train_scaled, X_val_scaled, X_test_scaled


def get_feature_importance(X_train: np.ndarray, y_train: np.ndarray, random_state: int = 42, n_jobs: int = -1) -> np.ndarray:
    """Get feature importance using Random Forest"""
    rf = RandomForestClassifier(
        n_estimators=1000,
        n_jobs=n_jobs,
        random_state=random_state,
        class_weight='balanced'
    )
    rf.fit(X_train, y_train)
    return rf.feature_importances_


def optimize_hyperparameters(X_train: np.ndarray, y_train: np.ndarray, estimator, param_grid: dict) -> Any:
    """Optimize hyperparameters using GridSearchCV"""
    random_search = RandomizedSearchCV(
        estimator=estimator, 
        param_distributions=param_grid,
        n_iter=25, 
        scoring='roc_auc',
        cv=3,
        n_jobs=-1,
        random_state=42
    )

    random_search.fit(X_train, y_train)
    return random_search


def test_different_numbers_of_features_cv(X_train: np.ndarray, X_val: np.ndarray, y_train: np.ndarray, y_val: np.ndarray,
                                          estimator, param_grid: dict, cv_folds: int = 5, max_features: int = 150) -> dict:
    """Test different numbers of features using cross-validation on training set, validate on validation set.
    Hyperparameter optimization is only done once at the end for the best feature set."""
    result_dict: dict = {}

    # Smart feature range selection
    min_features = 5
    feature_steps = 2
    feature_range = range(min_features, max_features + 1, feature_steps)

    # Get feature importance using the training set only (done once)
    feature_importance = get_feature_importance(X_train, y_train)

    for n_features in feature_range:
        print(f"Testing {n_features} features...")

        # Select top features
        top_features_idx = np.argsort(feature_importance)[-n_features:]
        X_train_subset = X_train[:, top_features_idx]
        X_val_subset = X_val[:, top_features_idx]

        # Evaluate using default estimator parameters with cross-validation on training set
        cv_scores = cross_val_score(
            estimator,
            X_train_subset,
            y_train,
            cv=cv_folds,
            scoring='roc_auc',
            n_jobs=-1
        )

        mean_cv_score = cv_scores.mean()
        std_cv_score = cv_scores.std()

        # Also evaluate on the separate validation set using default parameters
        temp_model = clone(estimator)
        temp_model.fit(X_train_subset, y_train)
        y_val_pred_proba = temp_model.predict_proba(X_val_subset)[:, 1]
        val_roc_auc = roc_auc_score(y_val, y_val_pred_proba)

        result_dict[n_features] = {
            'train_cv_mean': mean_cv_score,
            'train_cv_std': std_cv_score,
            'train_cv_scores': cv_scores,
            'val_roc_auc': val_roc_auc,
            'feature_indices': top_features_idx
        }
        print(f"Features: {n_features}, Train CV ROC AUC: {mean_cv_score:.4f} (+/- {std_cv_score * 2:.4f}), Val ROC AUC: {val_roc_auc:.4f}")

    # Find the best number of features based on cross-validation score
    best_n_features = max(result_dict.keys(), key=lambda k: result_dict[k]['train_cv_mean'])
    print(f"\nBest number of features: {best_n_features}")
    print(f"Optimizing hyperparameters for {best_n_features} features...")

    # Get the best feature subset
    best_features_idx = result_dict[best_n_features]['feature_indices']
    X_train_best = X_train[:, best_features_idx]
    X_val_best = X_val[:, best_features_idx]

    # Now optimize hyperparameters only for the best feature set
    grid_search = optimize_hyperparameters(X_train_best, y_train, estimator, param_grid)

    # Update the results for the best feature set with optimized hyperparameters
    best_estimator = grid_search.best_estimator_

    # Re-evaluate with optimized hyperparameters
    cv_scores_optimized = cross_val_score(
        best_estimator,
        X_train_best,
        y_train,
        cv=cv_folds,
        scoring='roc_auc',
        n_jobs=-1
    )

    # Final validation with optimized model
    final_model = clone(best_estimator)
    final_model.fit(X_train_best, y_train)
    y_val_pred_proba_optimized = final_model.predict_proba(X_val_best)[:, 1]
    val_roc_auc_optimized = roc_auc_score(y_val, y_val_pred_proba_optimized)

    # Update the best feature set results with optimized hyperparameters
    result_dict[best_n_features].update({
        'train_cv_mean_optimized': cv_scores_optimized.mean(),
        'train_cv_std_optimized': cv_scores_optimized.std(),
        'train_cv_scores_optimized': cv_scores_optimized,
        'val_roc_auc_optimized': val_roc_auc_optimized,
        'best_params': grid_search.best_params_,
        'best_model': grid_search.best_estimator_,
        'hyperparameter_cv_score': grid_search.best_score_
    })

    print(f"Optimized - Features: {best_n_features}, Train CV ROC AUC: {cv_scores_optimized.mean():.4f} (+/- {cv_scores_optimized.std() * 2:.4f}), Val ROC AUC: {val_roc_auc_optimized:.4f}")

    return result_dict


def evaluate_model_cv(estimator, scaler_name: str, scaler: Any, X_train: np.ndarray, X_val: np.ndarray, X_test: np.ndarray,
                      y_train: np.ndarray, y_val: np.ndarray, param_grid: dict, cv_folds: int = 5, max_features: int = 150) -> dict:
    """Evaluate a single scaler configuration using cross-validation for feature selection"""
    estimator_name = estimator.__class__.__name__
    print(f"Testing {scaler_name} for {estimator_name}...")

    # Apply scaling
    X_train_scaled, X_val_scaled, X_test_scaled = apply_scaling(scaler, X_train, X_val, X_test)

    # Test different feature counts using cross-validation
    results: dict = test_different_numbers_of_features_cv(
        X_train_scaled, X_val_scaled, y_train, y_val, estimator, param_grid, cv_folds, max_features
    )

    best_n_features = max(results, key=lambda x: results[x]['train_cv_mean'])
    # Use CV-based selection by default, but you can change this
    best_result = results[best_n_features]

    print(f"Best for {scaler_name} with {estimator_name}: CV {best_result['train_cv_mean']:.4f}, Val {best_result['val_roc_auc']:.4f} with {best_n_features} features")
    print()

    return {
        'estimator_name': estimator_name,
        'scaler_name': scaler_name,
        'scaler': scaler,
        'best_n_features': best_n_features,
        'best_result': best_result,
        'scaled_data': (X_train_scaled, X_val_scaled, X_test_scaled),
        'all_results': results
    }


def find_best_configuration_cv(X_train: np.ndarray, X_val: np.ndarray, X_test: np.ndarray,
                               y_train: np.ndarray, y_val: np.ndarray, config: Config) -> tuple[dict, list]:
    """Find the best scaler and feature configuration using cross-validation for feature selection"""
    best_overall_score = 0
    best_config = None
    all_results = []

    for scaler_name, scaler in config.scalers.items():
        for estimator, param_grid in config.models_and_param_grid:
            result = evaluate_model_cv(
                estimator, scaler_name, scaler, X_train, X_val, X_test, y_train, y_val, param_grid, config.cv_folds
            )
            all_results.append(result)

            best_result = result['best_result']
            # Select based on CV score for more robust selection
            best_cv_score = best_result['train_cv_mean']

            if best_cv_score > best_overall_score:
                best_overall_score = best_cv_score
                best_config = result

    if best_config is None:
        raise ValueError("No successful configuration found!")

    print(f"Best overall: {best_config['scaler_name']} with CV mean ROC AUC: {best_overall_score:.4f}")
    return best_config, all_results


def select_final_features(X_train: np.ndarray, X_val: np.ndarray, X_test: np.ndarray, feature_indices: np.ndarray) -> tuple[
    np.ndarray, np.ndarray, np.ndarray]:
    """Select final features based on indices"""
    X_train_final = X_train[:, feature_indices]
    X_val_final = X_val[:, feature_indices]
    X_test_final = X_test[:, feature_indices]
    return X_train_final, X_val_final, X_test_final


def train_final_model_cv(best_config: dict, y_train: np.ndarray, y_val: np.ndarray, feature_names: np.ndarray) -> dict:
    """Train final model using the best configuration found via CV"""
    best_result = best_config['best_result']

    # Get scaled data and feature indices
    X_train_scaled, X_val_scaled, X_test_scaled = best_config['scaled_data']
    feature_indices = best_result['feature_indices']

    # Select final features
    X_train_final, X_val_final, X_test_final = select_final_features(X_train_scaled, X_val_scaled, X_test_scaled, feature_indices)

    # Train the final model on training data
    final_model = clone(best_result['best_model'])
    final_model.fit(X_train_final, y_train)

    # Evaluate on validation set
    y_val_pred_proba = final_model.predict_proba(X_val_final)[:, 1]
    final_val_roc_auc = roc_auc_score(y_val, y_val_pred_proba)

    # Generate test predictions
    test_predictions = final_model.predict_proba(X_test_final)[:, 1]

    return {
        'final_model': final_model,
        'train_cv_score': best_result['train_cv_mean'],
        'train_cv_std': best_result['train_cv_std'],
        'val_roc_auc': final_val_roc_auc,
        'best_scaler': best_config['scaler'],
        'best_scaler_name': best_config['scaler_name'],
        'best_n_features': best_config['best_n_features'],
        'feature_names': feature_names[feature_indices],
        'best_params': best_result['best_params'],
        'test_predictions': test_predictions
    }


def validate_inputs_cv(X_train, y_train, X_val, y_val, X_test) -> tuple[np.ndarray, ...]:
    """Validate and convert inputs to consistent format for CV approach"""
    # Validate feature names
    feature_names = validate_feature_names(X_train.columns, X_train.shape[1])

    # Convert to numpy arrays
    X_train = to_numpy(X_train)
    X_val = to_numpy(X_val)
    X_test = to_numpy(X_test)
    y_train = to_numpy(y_train).ravel()
    y_val = to_numpy(y_val).ravel()

    # Basic validation
    assert X_train.shape[1] == X_val.shape[1] == X_test.shape[1], "Feature dimension mismatch"
    assert len(feature_names) == X_train.shape[1], "Feature names length mismatch"

    return X_train, y_train, X_val, y_val, X_test, feature_names


def optimized_feature_selection_cv(X_train, y_train, X_val, y_val, X_test, config) -> dict:
    """Main function for feature selection using cross-validation on training set"""
    # Validate inputs (keeping train/val separate)
    X_train, y_train, X_val, y_val, X_test, feature_names = validate_inputs_cv(
        X_train, y_train, X_val, y_val, X_test
    )

    # Find best configuration using CV on training set
    best_config, all_results = find_best_configuration_cv(X_train, X_val, X_test, y_train, y_val, config)

    # Train final model and evaluate
    result = train_final_model_cv(best_config, y_train, y_val, feature_names)
    result['all_evaluation_results'] = all_results

    return result

# %%
config: Config = create_default_config()

results = optimized_feature_selection_cv(
    X_train=X_train,
    y_train=y_train,
    X_val=X_val,
    y_val=y_val,
    X_test=X_test,
    config=config
)
# Out:
# Testing RobustScaler for LogisticRegression...
# Testing 5 features...
# Features: 5, Train CV ROC AUC: 0.8147 (+/- 0.0133), Val ROC AUC: 0.8060
# Testing 7 features...
# Features: 7, Train CV ROC AUC: 0.8147 (+/- 0.0133), Val ROC AUC: 0.8060
# Testing 9 features...
# Features: 9, Train CV ROC AUC: 0.8146 (+/- 0.0128), Val ROC AUC: 0.8053
# Testing 11 features...
# Features: 11, Train CV ROC AUC: 0.8145 (+/- 0.0128), Val ROC AUC: 0.8053
# Testing 13 features...
# Features: 13, Train CV ROC AUC: 0.8146 (+/- 0.0120), Val ROC AUC: 0.8057
# Testing 15 features...
# Features: 15, Train CV ROC AUC: 0.8181 (+/- 0.0143), Val ROC AUC: 0.8053
# Testing 17 features...
# Features: 17, Train CV ROC AUC: 0.8225 (+/- 0.0094), Val ROC AUC: 0.8102
# Testing 19 features...
# Features: 19, Train CV ROC AUC: 0.8269 (+/- 0.0072), Val ROC AUC: 0.8160
# Testing 21 features...
# Features: 21, Train CV ROC AUC: 0.8286 (+/- 0.0087), Val ROC AUC: 0.8169
# Testing 23 features...
# Features: 23, Train CV ROC AUC: 0.8312 (+/- 0.0087), Val ROC AUC: 0.8190
# Testing 25 features...
# Features: 25, Train CV ROC AUC: 0.8314 (+/- 0.0088), Val ROC AUC: 0.8192
# Testing 27 features...
# Features: 27, Train CV ROC AUC: 0.8350 (+/- 0.0084), Val ROC AUC: 0.8223
# Testing 29 features...
# Features: 29, Train CV ROC AUC: 0.8351 (+/- 0.0086), Val ROC AUC: 0.8225
# Testing 31 features...
# Features: 31, Train CV ROC AUC: 0.8356 (+/- 0.0081), Val ROC AUC: 0.8226
# Testing 33 features...
# Features: 33, Train CV ROC AUC: 0.8353 (+/- 0.0073), Val ROC AUC: 0.8229
# Testing 35 features...
# Features: 35, Train CV ROC AUC: 0.8355 (+/- 0.0072), Val ROC AUC: 0.8232
# Testing 37 features...
# Features: 37, Train CV ROC AUC: 0.8356 (+/- 0.0073), Val ROC AUC: 0.8233
# Testing 39 features...
# Features: 39, Train CV ROC AUC: 0.8358 (+/- 0.0071), Val ROC AUC: 0.8235
# Testing 41 features...
# Features: 41, Train CV ROC AUC: 0.8359 (+/- 0.0068), Val ROC AUC: 0.8234
# Testing 43 features...
# Features: 43, Train CV ROC AUC: 0.8380 (+/- 0.0076), Val ROC AUC: 0.8267
# Testing 45 features...
# Features: 45, Train CV ROC AUC: 0.8379 (+/- 0.0078), Val ROC AUC: 0.8266
# Testing 47 features...
# Features: 47, Train CV ROC AUC: 0.8380 (+/- 0.0076), Val ROC AUC: 0.8270
# Testing 49 features...
# Features: 49, Train CV ROC AUC: 0.8379 (+/- 0.0077), Val ROC AUC: 0.8270
# Testing 51 features...
# Features: 51, Train CV ROC AUC: 0.8380 (+/- 0.0077), Val ROC AUC: 0.8271
# Testing 53 features...
# Features: 53, Train CV ROC AUC: 0.8380 (+/- 0.0078), Val ROC AUC: 0.8272
# Testing 55 features...
# Features: 55, Train CV ROC AUC: 0.8378 (+/- 0.0077), Val ROC AUC: 0.8271
# Testing 57 features...
# Features: 57, Train CV ROC AUC: 0.8377 (+/- 0.0076), Val ROC AUC: 0.8272
# Testing 59 features...
# Features: 59, Train CV ROC AUC: 0.8378 (+/- 0.0077), Val ROC AUC: 0.8271
# Testing 61 features...
# Features: 61, Train CV ROC AUC: 0.8378 (+/- 0.0077), Val ROC AUC: 0.8271
# Testing 63 features...
# Features: 63, Train CV ROC AUC: 0.8380 (+/- 0.0076), Val ROC AUC: 0.8270
# Testing 65 features...
# Features: 65, Train CV ROC AUC: 0.8379 (+/- 0.0075), Val ROC AUC: 0.8270
# Testing 67 features...
# Features: 67, Train CV ROC AUC: 0.8379 (+/- 0.0075), Val ROC AUC: 0.8272
# Testing 69 features...
# Features: 69, Train CV ROC AUC: 0.8380 (+/- 0.0075), Val ROC AUC: 0.8274
# Testing 71 features...
# Features: 71, Train CV ROC AUC: 0.8378 (+/- 0.0075), Val ROC AUC: 0.8273
# Testing 73 features...
# Features: 73, Train CV ROC AUC: 0.8384 (+/- 0.0073), Val ROC AUC: 0.8279
# Testing 75 features...
# Features: 75, Train CV ROC AUC: 0.8385 (+/- 0.0070), Val ROC AUC: 0.8279
# Testing 77 features...
# Features: 77, Train CV ROC AUC: 0.8385 (+/- 0.0071), Val ROC AUC: 0.8280
# Testing 79 features...
# Features: 79, Train CV ROC AUC: 0.8384 (+/- 0.0071), Val ROC AUC: 0.8280
# Testing 81 features...
# Features: 81, Train CV ROC AUC: 0.8383 (+/- 0.0073), Val ROC AUC: 0.8279
# Testing 83 features...
# Features: 83, Train CV ROC AUC: 0.8382 (+/- 0.0074), Val ROC AUC: 0.8278
# Testing 85 features...
# Features: 85, Train CV ROC AUC: 0.8383 (+/- 0.0074), Val ROC AUC: 0.8278
# Testing 87 features...
# Features: 87, Train CV ROC AUC: 0.8386 (+/- 0.0079), Val ROC AUC: 0.8280
# Testing 89 features...
# Features: 89, Train CV ROC AUC: 0.8389 (+/- 0.0078), Val ROC AUC: 0.8281
# Testing 91 features...
# Features: 91, Train CV ROC AUC: 0.8389 (+/- 0.0080), Val ROC AUC: 0.8280
# Testing 93 features...
# Features: 93, Train CV ROC AUC: 0.8389 (+/- 0.0081), Val ROC AUC: 0.8279
# Testing 95 features...
# Features: 95, Train CV ROC AUC: 0.8387 (+/- 0.0082), Val ROC AUC: 0.8278
# Testing 97 features...
# Features: 97, Train CV ROC AUC: 0.8387 (+/- 0.0081), Val ROC AUC: 0.8278
# Testing 99 features...
# Features: 99, Train CV ROC AUC: 0.8387 (+/- 0.0080), Val ROC AUC: 0.8277
# Testing 101 features...
# Features: 101, Train CV ROC AUC: 0.8387 (+/- 0.0080), Val ROC AUC: 0.8278
# Testing 103 features...
# Features: 103, Train CV ROC AUC: 0.8386 (+/- 0.0080), Val ROC AUC: 0.8278
# Testing 105 features...
# Features: 105, Train CV ROC AUC: 0.8386 (+/- 0.0082), Val ROC AUC: 0.8276
# Testing 107 features...
# Features: 107, Train CV ROC AUC: 0.8386 (+/- 0.0081), Val ROC AUC: 0.8278
# Testing 109 features...
# Features: 109, Train CV ROC AUC: 0.8386 (+/- 0.0081), Val ROC AUC: 0.8279
# Testing 111 features...
# Features: 111, Train CV ROC AUC: 0.8387 (+/- 0.0081), Val ROC AUC: 0.8278
# Testing 113 features...
# Features: 113, Train CV ROC AUC: 0.8386 (+/- 0.0080), Val ROC AUC: 0.8281
# Testing 115 features...
# Features: 115, Train CV ROC AUC: 0.8387 (+/- 0.0082), Val ROC AUC: 0.8283
# Testing 117 features...
# Features: 117, Train CV ROC AUC: 0.8386 (+/- 0.0082), Val ROC AUC: 0.8283
# Testing 119 features...
# Features: 119, Train CV ROC AUC: 0.8386 (+/- 0.0081), Val ROC AUC: 0.8283
# Testing 121 features...
# Features: 121, Train CV ROC AUC: 0.8385 (+/- 0.0082), Val ROC AUC: 0.8283
# Testing 123 features...
# Features: 123, Train CV ROC AUC: 0.8385 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 125 features...
# Features: 125, Train CV ROC AUC: 0.8385 (+/- 0.0083), Val ROC AUC: 0.8283
# Testing 127 features...
# Features: 127, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 129 features...
# Features: 129, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 131 features...
# Features: 131, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 133 features...
# Features: 133, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 135 features...
# Features: 135, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 137 features...
# Features: 137, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 139 features...
# Features: 139, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 141 features...
# Features: 141, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 143 features...
# Features: 143, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 145 features...
# Features: 145, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 147 features...
# Features: 147, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 149 features...
# Features: 149, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
#
# Best number of features: 89
# Optimizing hyperparameters for 89 features...
# Optimized - Features: 89, Train CV ROC AUC: 0.8393 (+/- 0.0074), Val ROC AUC: 0.8287
# Best for RobustScaler with LogisticRegression: CV 0.8389, Val 0.8281 with 89 features
#
# Testing MinMaxScaler for LogisticRegression...
# Testing 5 features...
# Features: 5, Train CV ROC AUC: 0.8140 (+/- 0.0132), Val ROC AUC: 0.8057
# Testing 7 features...
# Features: 7, Train CV ROC AUC: 0.8144 (+/- 0.0134), Val ROC AUC: 0.8068
# Testing 9 features...
# Features: 9, Train CV ROC AUC: 0.8142 (+/- 0.0132), Val ROC AUC: 0.8050
# Testing 11 features...
# Features: 11, Train CV ROC AUC: 0.8142 (+/- 0.0129), Val ROC AUC: 0.8051
# Testing 13 features...
# Features: 13, Train CV ROC AUC: 0.8143 (+/- 0.0117), Val ROC AUC: 0.8060
# Testing 15 features...
# Features: 15, Train CV ROC AUC: 0.8178 (+/- 0.0080), Val ROC AUC: 0.8064
# Testing 17 features...
# Features: 17, Train CV ROC AUC: 0.8220 (+/- 0.0049), Val ROC AUC: 0.8120
# Testing 19 features...
# Features: 19, Train CV ROC AUC: 0.8260 (+/- 0.0071), Val ROC AUC: 0.8157
# Testing 21 features...
# Features: 21, Train CV ROC AUC: 0.8283 (+/- 0.0083), Val ROC AUC: 0.8180
# Testing 23 features...
# Features: 23, Train CV ROC AUC: 0.8304 (+/- 0.0078), Val ROC AUC: 0.8191
# Testing 25 features...
# Features: 25, Train CV ROC AUC: 0.8323 (+/- 0.0090), Val ROC AUC: 0.8207
# Testing 27 features...
# Features: 27, Train CV ROC AUC: 0.8339 (+/- 0.0087), Val ROC AUC: 0.8221
# Testing 29 features...
# Features: 29, Train CV ROC AUC: 0.8345 (+/- 0.0084), Val ROC AUC: 0.8225
# Testing 31 features...
# Features: 31, Train CV ROC AUC: 0.8346 (+/- 0.0084), Val ROC AUC: 0.8223
# Testing 33 features...
# Features: 33, Train CV ROC AUC: 0.8342 (+/- 0.0071), Val ROC AUC: 0.8229
# Testing 35 features...
# Features: 35, Train CV ROC AUC: 0.8346 (+/- 0.0071), Val ROC AUC: 0.8227
# Testing 37 features...
# Features: 37, Train CV ROC AUC: 0.8348 (+/- 0.0071), Val ROC AUC: 0.8228
# Testing 39 features...
# Features: 39, Train CV ROC AUC: 0.8348 (+/- 0.0071), Val ROC AUC: 0.8232
# Testing 41 features...
# Features: 41, Train CV ROC AUC: 0.8369 (+/- 0.0069), Val ROC AUC: 0.8258
# Testing 43 features...
# Features: 43, Train CV ROC AUC: 0.8369 (+/- 0.0067), Val ROC AUC: 0.8260
# Testing 45 features...
# Features: 45, Train CV ROC AUC: 0.8370 (+/- 0.0065), Val ROC AUC: 0.8261
# Testing 47 features...
# Features: 47, Train CV ROC AUC: 0.8369 (+/- 0.0064), Val ROC AUC: 0.8265
# Testing 49 features...
# Features: 49, Train CV ROC AUC: 0.8370 (+/- 0.0066), Val ROC AUC: 0.8265
# Testing 51 features...
# Features: 51, Train CV ROC AUC: 0.8369 (+/- 0.0069), Val ROC AUC: 0.8266
# Testing 53 features...
# Features: 53, Train CV ROC AUC: 0.8369 (+/- 0.0069), Val ROC AUC: 0.8262
# Testing 55 features...
# Features: 55, Train CV ROC AUC: 0.8369 (+/- 0.0070), Val ROC AUC: 0.8265
# Testing 57 features...
# Features: 57, Train CV ROC AUC: 0.8369 (+/- 0.0070), Val ROC AUC: 0.8266
# Testing 59 features...
# Features: 59, Train CV ROC AUC: 0.8368 (+/- 0.0067), Val ROC AUC: 0.8265
# Testing 61 features...
# Features: 61, Train CV ROC AUC: 0.8366 (+/- 0.0063), Val ROC AUC: 0.8261
# Testing 63 features...
# Features: 63, Train CV ROC AUC: 0.8370 (+/- 0.0067), Val ROC AUC: 0.8261
# Testing 65 features...
# Features: 65, Train CV ROC AUC: 0.8370 (+/- 0.0065), Val ROC AUC: 0.8261
# Testing 67 features...
# Features: 67, Train CV ROC AUC: 0.8370 (+/- 0.0067), Val ROC AUC: 0.8259
# Testing 69 features...
# Features: 69, Train CV ROC AUC: 0.8371 (+/- 0.0066), Val ROC AUC: 0.8264
# Testing 71 features...
# Features: 71, Train CV ROC AUC: 0.8370 (+/- 0.0070), Val ROC AUC: 0.8262
# Testing 73 features...
# Features: 73, Train CV ROC AUC: 0.8377 (+/- 0.0068), Val ROC AUC: 0.8265
# Testing 75 features...
# Features: 75, Train CV ROC AUC: 0.8378 (+/- 0.0063), Val ROC AUC: 0.8269
# Testing 77 features...
# Features: 77, Train CV ROC AUC: 0.8378 (+/- 0.0065), Val ROC AUC: 0.8271
# Testing 79 features...
# Features: 79, Train CV ROC AUC: 0.8377 (+/- 0.0064), Val ROC AUC: 0.8270
# Testing 81 features...
# Features: 81, Train CV ROC AUC: 0.8374 (+/- 0.0063), Val ROC AUC: 0.8271
# Testing 83 features...
# Features: 83, Train CV ROC AUC: 0.8376 (+/- 0.0065), Val ROC AUC: 0.8270
# Testing 85 features...
# Features: 85, Train CV ROC AUC: 0.8376 (+/- 0.0065), Val ROC AUC: 0.8269
# Testing 87 features...
# Features: 87, Train CV ROC AUC: 0.8379 (+/- 0.0067), Val ROC AUC: 0.8272
# Testing 89 features...
# Features: 89, Train CV ROC AUC: 0.8384 (+/- 0.0071), Val ROC AUC: 0.8276
# Testing 91 features...
# Features: 91, Train CV ROC AUC: 0.8383 (+/- 0.0069), Val ROC AUC: 0.8274
# Testing 93 features...
# Features: 93, Train CV ROC AUC: 0.8384 (+/- 0.0070), Val ROC AUC: 0.8271
# Testing 95 features...
# Features: 95, Train CV ROC AUC: 0.8381 (+/- 0.0072), Val ROC AUC: 0.8270
# Testing 97 features...
# Features: 97, Train CV ROC AUC: 0.8382 (+/- 0.0072), Val ROC AUC: 0.8270
# Testing 99 features...
# Features: 99, Train CV ROC AUC: 0.8380 (+/- 0.0072), Val ROC AUC: 0.8267
# Testing 101 features...
# Features: 101, Train CV ROC AUC: 0.8378 (+/- 0.0072), Val ROC AUC: 0.8270
# Testing 103 features...
# Features: 103, Train CV ROC AUC: 0.8380 (+/- 0.0071), Val ROC AUC: 0.8269
# Testing 105 features...
# Features: 105, Train CV ROC AUC: 0.8380 (+/- 0.0074), Val ROC AUC: 0.8268
# Testing 107 features...
# Features: 107, Train CV ROC AUC: 0.8381 (+/- 0.0070), Val ROC AUC: 0.8271
# Testing 109 features...
# Features: 109, Train CV ROC AUC: 0.8381 (+/- 0.0069), Val ROC AUC: 0.8266
# Testing 111 features...
# Features: 111, Train CV ROC AUC: 0.8381 (+/- 0.0067), Val ROC AUC: 0.8272
# Testing 113 features...
# Features: 113, Train CV ROC AUC: 0.8375 (+/- 0.0059), Val ROC AUC: 0.8278
# Testing 115 features...
# Features: 115, Train CV ROC AUC: 0.8382 (+/- 0.0072), Val ROC AUC: 0.8275
# Testing 117 features...
# Features: 117, Train CV ROC AUC: 0.8378 (+/- 0.0075), Val ROC AUC: 0.8278
# Testing 119 features...
# Features: 119, Train CV ROC AUC: 0.8381 (+/- 0.0072), Val ROC AUC: 0.8273
# Testing 121 features...
# Features: 121, Train CV ROC AUC: 0.8380 (+/- 0.0072), Val ROC AUC: 0.8278
# Testing 123 features...
# Features: 123, Train CV ROC AUC: 0.8375 (+/- 0.0077), Val ROC AUC: 0.8272
# Testing 125 features...
# Features: 125, Train CV ROC AUC: 0.8369 (+/- 0.0072), Val ROC AUC: 0.8276
# Testing 127 features...
# Features: 127, Train CV ROC AUC: 0.8368 (+/- 0.0074), Val ROC AUC: 0.8274
# Testing 129 features...
# Features: 129, Train CV ROC AUC: 0.8368 (+/- 0.0074), Val ROC AUC: 0.8274
# Testing 131 features...
# Features: 131, Train CV ROC AUC: 0.8368 (+/- 0.0074), Val ROC AUC: 0.8274
# Testing 133 features...
# Features: 133, Train CV ROC AUC: 0.8368 (+/- 0.0074), Val ROC AUC: 0.8274
# Testing 135 features...
# Features: 135, Train CV ROC AUC: 0.8368 (+/- 0.0074), Val ROC AUC: 0.8274
# Testing 137 features...
# Features: 137, Train CV ROC AUC: 0.8368 (+/- 0.0074), Val ROC AUC: 0.8274
# Testing 139 features...
# Features: 139, Train CV ROC AUC: 0.8368 (+/- 0.0074), Val ROC AUC: 0.8274
# Testing 141 features...
# Features: 141, Train CV ROC AUC: 0.8368 (+/- 0.0074), Val ROC AUC: 0.8274
# Testing 143 features...
# Features: 143, Train CV ROC AUC: 0.8368 (+/- 0.0074), Val ROC AUC: 0.8274
# Testing 145 features...
# Features: 145, Train CV ROC AUC: 0.8368 (+/- 0.0074), Val ROC AUC: 0.8274
# Testing 147 features...
# Features: 147, Train CV ROC AUC: 0.8368 (+/- 0.0074), Val ROC AUC: 0.8274
# Testing 149 features...
# Features: 149, Train CV ROC AUC: 0.8368 (+/- 0.0074), Val ROC AUC: 0.8274
#
# Best number of features: 89
# Optimizing hyperparameters for 89 features...
# Optimized - Features: 89, Train CV ROC AUC: 0.8390 (+/- 0.0079), Val ROC AUC: 0.8282
# Best for MinMaxScaler with LogisticRegression: CV 0.8384, Val 0.8276 with 89 features
#
# Testing StandardScaler for LogisticRegression...
# Testing 5 features...
# Features: 5, Train CV ROC AUC: 0.8147 (+/- 0.0133), Val ROC AUC: 0.8060
# Testing 7 features...
# Features: 7, Train CV ROC AUC: 0.8147 (+/- 0.0133), Val ROC AUC: 0.8060
# Testing 9 features...
# Features: 9, Train CV ROC AUC: 0.8146 (+/- 0.0128), Val ROC AUC: 0.8053
# Testing 11 features...
# Features: 11, Train CV ROC AUC: 0.8145 (+/- 0.0128), Val ROC AUC: 0.8053
# Testing 13 features...
# Features: 13, Train CV ROC AUC: 0.8146 (+/- 0.0120), Val ROC AUC: 0.8057
# Testing 15 features...
# Features: 15, Train CV ROC AUC: 0.8184 (+/- 0.0082), Val ROC AUC: 0.8065
# Testing 17 features...
# Features: 17, Train CV ROC AUC: 0.8225 (+/- 0.0094), Val ROC AUC: 0.8102
# Testing 19 features...
# Features: 19, Train CV ROC AUC: 0.8268 (+/- 0.0072), Val ROC AUC: 0.8160
# Testing 21 features...
# Features: 21, Train CV ROC AUC: 0.8274 (+/- 0.0076), Val ROC AUC: 0.8163
# Testing 23 features...
# Features: 23, Train CV ROC AUC: 0.8292 (+/- 0.0084), Val ROC AUC: 0.8174
# Testing 25 features...
# Features: 25, Train CV ROC AUC: 0.8333 (+/- 0.0087), Val ROC AUC: 0.8210
# Testing 27 features...
# Features: 27, Train CV ROC AUC: 0.8333 (+/- 0.0086), Val ROC AUC: 0.8209
# Testing 29 features...
# Features: 29, Train CV ROC AUC: 0.8351 (+/- 0.0085), Val ROC AUC: 0.8225
# Testing 31 features...
# Features: 31, Train CV ROC AUC: 0.8355 (+/- 0.0081), Val ROC AUC: 0.8226
# Testing 33 features...
# Features: 33, Train CV ROC AUC: 0.8355 (+/- 0.0070), Val ROC AUC: 0.8232
# Testing 35 features...
# Features: 35, Train CV ROC AUC: 0.8355 (+/- 0.0073), Val ROC AUC: 0.8230
# Testing 37 features...
# Features: 37, Train CV ROC AUC: 0.8356 (+/- 0.0073), Val ROC AUC: 0.8232
# Testing 39 features...
# Features: 39, Train CV ROC AUC: 0.8358 (+/- 0.0069), Val ROC AUC: 0.8234
# Testing 41 features...
# Features: 41, Train CV ROC AUC: 0.8359 (+/- 0.0068), Val ROC AUC: 0.8234
# Testing 43 features...
# Features: 43, Train CV ROC AUC: 0.8379 (+/- 0.0076), Val ROC AUC: 0.8265
# Testing 45 features...
# Features: 45, Train CV ROC AUC: 0.8378 (+/- 0.0079), Val ROC AUC: 0.8266
# Testing 47 features...
# Features: 47, Train CV ROC AUC: 0.8380 (+/- 0.0076), Val ROC AUC: 0.8270
# Testing 49 features...
# Features: 49, Train CV ROC AUC: 0.8379 (+/- 0.0077), Val ROC AUC: 0.8270
# Testing 51 features...
# Features: 51, Train CV ROC AUC: 0.8380 (+/- 0.0077), Val ROC AUC: 0.8271
# Testing 53 features...
# Features: 53, Train CV ROC AUC: 0.8380 (+/- 0.0078), Val ROC AUC: 0.8272
# Testing 55 features...
# Features: 55, Train CV ROC AUC: 0.8379 (+/- 0.0079), Val ROC AUC: 0.8273
# Testing 57 features...
# Features: 57, Train CV ROC AUC: 0.8380 (+/- 0.0079), Val ROC AUC: 0.8272
# Testing 59 features...
# Features: 59, Train CV ROC AUC: 0.8378 (+/- 0.0076), Val ROC AUC: 0.8271
# Testing 61 features...
# Features: 61, Train CV ROC AUC: 0.8378 (+/- 0.0076), Val ROC AUC: 0.8272
# Testing 63 features...
# Features: 63, Train CV ROC AUC: 0.8380 (+/- 0.0077), Val ROC AUC: 0.8271
# Testing 65 features...
# Features: 65, Train CV ROC AUC: 0.8380 (+/- 0.0076), Val ROC AUC: 0.8271
# Testing 67 features...
# Features: 67, Train CV ROC AUC: 0.8379 (+/- 0.0076), Val ROC AUC: 0.8272
# Testing 69 features...
# Features: 69, Train CV ROC AUC: 0.8380 (+/- 0.0075), Val ROC AUC: 0.8274
# Testing 71 features...
# Features: 71, Train CV ROC AUC: 0.8384 (+/- 0.0072), Val ROC AUC: 0.8279
# Testing 73 features...
# Features: 73, Train CV ROC AUC: 0.8386 (+/- 0.0069), Val ROC AUC: 0.8279
# Testing 75 features...
# Features: 75, Train CV ROC AUC: 0.8385 (+/- 0.0070), Val ROC AUC: 0.8279
# Testing 77 features...
# Features: 77, Train CV ROC AUC: 0.8385 (+/- 0.0071), Val ROC AUC: 0.8280
# Testing 79 features...
# Features: 79, Train CV ROC AUC: 0.8384 (+/- 0.0071), Val ROC AUC: 0.8280
# Testing 81 features...
# Features: 81, Train CV ROC AUC: 0.8384 (+/- 0.0073), Val ROC AUC: 0.8278
# Testing 83 features...
# Features: 83, Train CV ROC AUC: 0.8382 (+/- 0.0074), Val ROC AUC: 0.8278
# Testing 85 features...
# Features: 85, Train CV ROC AUC: 0.8383 (+/- 0.0075), Val ROC AUC: 0.8278
# Testing 87 features...
# Features: 87, Train CV ROC AUC: 0.8389 (+/- 0.0079), Val ROC AUC: 0.8282
# Testing 89 features...
# Features: 89, Train CV ROC AUC: 0.8389 (+/- 0.0079), Val ROC AUC: 0.8281
# Testing 91 features...
# Features: 91, Train CV ROC AUC: 0.8389 (+/- 0.0080), Val ROC AUC: 0.8280
# Testing 93 features...
# Features: 93, Train CV ROC AUC: 0.8388 (+/- 0.0081), Val ROC AUC: 0.8279
# Testing 95 features...
# Features: 95, Train CV ROC AUC: 0.8388 (+/- 0.0082), Val ROC AUC: 0.8279
# Testing 97 features...
# Features: 97, Train CV ROC AUC: 0.8387 (+/- 0.0081), Val ROC AUC: 0.8278
# Testing 99 features...
# Features: 99, Train CV ROC AUC: 0.8387 (+/- 0.0082), Val ROC AUC: 0.8278
# Testing 101 features...
# Features: 101, Train CV ROC AUC: 0.8386 (+/- 0.0080), Val ROC AUC: 0.8276
# Testing 103 features...
# Features: 103, Train CV ROC AUC: 0.8386 (+/- 0.0081), Val ROC AUC: 0.8277
# Testing 105 features...
# Features: 105, Train CV ROC AUC: 0.8386 (+/- 0.0082), Val ROC AUC: 0.8276
# Testing 107 features...
# Features: 107, Train CV ROC AUC: 0.8385 (+/- 0.0081), Val ROC AUC: 0.8278
# Testing 109 features...
# Features: 109, Train CV ROC AUC: 0.8386 (+/- 0.0081), Val ROC AUC: 0.8279
# Testing 111 features...
# Features: 111, Train CV ROC AUC: 0.8387 (+/- 0.0081), Val ROC AUC: 0.8278
# Testing 113 features...
# Features: 113, Train CV ROC AUC: 0.8387 (+/- 0.0081), Val ROC AUC: 0.8277
# Testing 115 features...
# Features: 115, Train CV ROC AUC: 0.8386 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 117 features...
# Features: 117, Train CV ROC AUC: 0.8386 (+/- 0.0082), Val ROC AUC: 0.8282
# Testing 119 features...
# Features: 119, Train CV ROC AUC: 0.8386 (+/- 0.0081), Val ROC AUC: 0.8282
# Testing 121 features...
# Features: 121, Train CV ROC AUC: 0.8385 (+/- 0.0082), Val ROC AUC: 0.8282
# Testing 123 features...
# Features: 123, Train CV ROC AUC: 0.8385 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 125 features...
# Features: 125, Train CV ROC AUC: 0.8385 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 127 features...
# Features: 127, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 129 features...
# Features: 129, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 131 features...
# Features: 131, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 133 features...
# Features: 133, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 135 features...
# Features: 135, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 137 features...
# Features: 137, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 139 features...
# Features: 139, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 141 features...
# Features: 141, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 143 features...
# Features: 143, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 145 features...
# Features: 145, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 147 features...
# Features: 147, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
# Testing 149 features...
# Features: 149, Train CV ROC AUC: 0.8384 (+/- 0.0083), Val ROC AUC: 0.8282
#
# Best number of features: 89
# Optimizing hyperparameters for 89 features...
# Optimized - Features: 89, Train CV ROC AUC: 0.8394 (+/- 0.0076), Val ROC AUC: 0.8288
# Best for StandardScaler with LogisticRegression: CV 0.8389, Val 0.8281 with 89 features
#
# Best overall: RobustScaler with CV mean ROC AUC: 0.8389

# %%
print(results)
# Out:
# {'final_model': LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000, penalty='l1',
#                    solver='liblinear'), 'train_cv_score': np.float64(0.8389293551874845), 'train_cv_std': np.float64(0.003924991296490205), 'val_roc_auc': np.float64(0.8286702407299251), 'best_scaler': RobustScaler(), 'best_scaler_name': 'RobustScaler', 'best_n_features': 89, 'feature_names': array(['r2_level_lead', 'r2_kills_lead', 'r1_kills_lead', 'r1_level_lead',
#        'r5_kills_lead', 'r3_kills_lead', 'r4_rune_pickups_lead',
#        'r4_assists_lead', 'r3_rune_pickups_lead', 'r5_rune_pickups_lead',
#        'r1_rune_pickups_lead', 'r5_assists_lead', 'r5_level_lead',
#        'r4_level_lead', 'r2_rune_pickups_lead', 'r1_denies_lead',
#        'r2_denies_lead', 'r3_level_lead', 'r3_assists_lead',
#        'r4_kills_lead', 'r4_denies_lead', 'r2_lh_lead', 'r5_denies_lead',
#        'r1_lh_lead', 'r2_stuns_lead', 'r5_stuns_lead', 'r1_stuns_lead',
#        'r3_denies_lead', 'r4_stuns_lead',
#        'r1_teamfight_participation_lead', 'r3_stuns_lead',
#        'r1_assists_lead', 'r2_teamfight_participation_lead',
#        'r4_teamfight_participation_lead',
#        'r5_teamfight_participation_lead', 'r4_lh_lead',
#        'r3_teamfight_participation_lead', 'r3_lh_lead', 'r5_lh_lead',
#        'r2_max_health_lead', 'r1_max_health_lead', 'r1_deaths_lead',
#        'r5_max_health_lead', 'r2_assists_lead', 'radiant_team_xp',
#        'r3_max_health_lead', 'radiant_carry_%_team_gold',
#        'r1_max_mana_lead', 'r4_max_mana_lead', 'r2_max_mana_lead',
#        'r1_health_lead', 'r5_max_mana_lead', 'r3_max_mana_lead',
#        'game_time', 'r2_health_lead', 'r4_max_health_lead',
#        'radiant_team_gold', 'r3_deaths_lead', 'r2_xp_lead',
#        'r4_health_lead', 'r5_health_lead', 'r1_xp_lead',
#        'r1_hero_winrate', 'r3_hero_winrate', 'r2_deaths_lead',
#        'r5_deaths_lead', 'r3_health_lead', 'd1_hero_winrate',
#        'radiant_carry_%_total_gold', 'r2_hero_winrate', 'd3_hero_winrate',
#        'r4_hero_winrate', 'r5_hero_winrate', 'd2_hero_winrate',
#        'd5_hero_winrate', 'd4_hero_winrate', 'r4_deaths_lead',
#        'r5_xp_lead', 'r4_xp_lead', 'r2_gold_lead', 'r3_xp_lead',
#        'r1_gold_lead', 'r5_gold_lead', 'r3_gold_lead', 'r4_gold_lead',
#        'radiant_carries_xp_lead', 'radiant_carries_gold_lead',
#        'radiant_team_xp_lead', 'radiant_team_gold_lead'], dtype=object), 'best_params': {'solver': 'liblinear', 'penalty': 'l1', 'max_iter': 1000, 'class_weight': 'balanced', 'C': 0.1}, 'test_predictions': array([0.1345186 , 0.44494921, 0.61268518, ..., 0.17305622, 0.8765627 ,
#        0.84158831], shape=(10000,)), 'all_evaluation_results': [{'estimator_name': 'LogisticRegression', 'scaler_name': 'RobustScaler', 'scaler': RobustScaler(), 'best_n_features': 89, 'best_result': {'train_cv_mean': np.float64(0.8389293551874845), 'train_cv_std': np.float64(0.003924991296490205), 'train_cv_scores': array([0.84446959, 0.83645538, 0.83586309]), 'val_roc_auc': np.float64(0.8281016949770258), 'feature_indices': array([ 47,  37,  14,  24, 106,  60,  97,  85,  74, 120,  28, 108, 116,
#         93,  51,  17,  40,  70,  62,  83,  86,  42, 109,  19,  48, 117,
#         25,  63,  94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,
#         45,  22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,
#         69,   0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38,
#        107,  67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,
#         89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7]), 'train_cv_mean_optimized': np.float64(0.8393412410916516), 'train_cv_std_optimized': np.float64(0.0037163542291336095), 'train_cv_scores_optimized': array([0.84458138, 0.83707135, 0.83637099]), 'val_roc_auc_optimized': np.float64(0.8286671656627521), 'best_params': {'solver': 'liblinear', 'penalty': 'l1', 'max_iter': 1000, 'class_weight': 'balanced', 'C': 0.1}, 'best_model': LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000, penalty='l1',
#                    solver='liblinear'), 'hyperparameter_cv_score': np.float64(0.8393545512232349)}, 'scaled_data': (array([[  1.61558669,   0.        ,   0.        , ...,   0.        ,
#          -5.5       ,  -7.        ],
#        [  0.67250438, -19.        ,   0.        , ...,   0.        ,
#           4.5       ,   6.        ],
#        [ -0.10770578,   0.        ,   0.        , ...,   0.        ,
#           0.        ,   0.        ],
#        ...,
#        [ -0.49211909,   0.        ,   0.        , ...,   0.        ,
#           0.        ,   0.        ],
#        [  0.43345009,   0.        ,   0.        , ...,   0.        ,
#           2.5       ,   8.        ],
#        [  0.3441331 ,   0.        ,   0.        , ...,   0.        ,
#           3.5       ,   7.        ]], shape=(23740, 127)), array([[ 0.05516637,  0.        ,  0.        , ...,  0.        ,
#          0.5       ,  1.        ],
#        [ 0.02714536,  0.        , -1.        , ...,  0.        ,
#         -1.5       , -1.        ],
#        [ 0.20577933,  1.        , -1.        , ...,  0.        ,
#         -2.        , -6.        ],
#        ...,
#        [ 0.36952715,  0.        ,  0.        , ...,  0.        ,
#          0.        , -1.        ],
#        [ 0.44308231,  0.        , -1.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.15061296,  1.        , -1.        , ...,  1.        ,
#         -1.5       ,  0.        ]], shape=(5935, 127)), array([[ -0.78371278,   0.        ,   0.        , ...,   0.        ,
#           0.        ,   0.        ],
#        [  0.2732049 , -18.        ,  -1.        , ...,   0.        ,
#           0.        ,   0.        ],
#        [  1.17162872, -18.        ,  -1.        , ...,   0.        ,
#           0.        ,   0.        ],
#        ...,
#        [ -0.35639229,   0.        ,   0.        , ...,   0.        ,
#           0.        ,   1.        ],
#        [  1.18651489,   0.        ,   0.        , ...,   1.        ,
#           0.        ,   0.        ],
#        [  0.63485114,   0.        ,  -1.        , ...,   0.        ,
#           4.        ,   4.        ]], shape=(10000, 127))), 'all_results': {5: {'train_cv_mean': np.float64(0.8147467556643858), 'train_cv_std': np.float64(0.006629670596826852), 'train_cv_scores': array([0.82405287, 0.80910577, 0.81108163]), 'val_roc_auc': np.float64(0.8059855840850922), 'feature_indices': array([87, 11,  8, 10,  7])}, 7: {'train_cv_mean': np.float64(0.8146840965403778), 'train_cv_std': np.float64(0.0066300122433582106), 'train_cv_scores': array([0.82399118, 0.80904604, 0.81101507]), 'val_roc_auc': np.float64(0.8059678170303142), 'feature_indices': array([110,  64,  87,  11,   8,  10,   7])}, 9: {'train_cv_mean': np.float64(0.8145659930400809), 'train_cv_std': np.float64(0.006416031394430399), 'train_cv_scores': array([0.82359916, 0.80930807, 0.81079075]), 'val_roc_auc': np.float64(0.8052905050125873), 'feature_indices': array([ 66,  18, 110,  64,  87,  11,   8,  10,   7])}, 11: {'train_cv_mean': np.float64(0.8144866305160076), 'train_cv_std': np.float64(0.006404394955487553), 'train_cv_scores': array([0.82350554, 0.80925686, 0.81069749]), 'val_roc_auc': np.float64(0.805268068411361), 'feature_indices': array([ 89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 13: {'train_cv_mean': np.float64(0.814583155673613), 'train_cv_std': np.float64(0.005983985532666576), 'train_cv_scores': array([0.8229792 , 0.80946758, 0.81130269]), 'val_roc_auc': np.float64(0.8057147503911031), 'feature_indices': array([ 84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 15: {'train_cv_mean': np.float64(0.8180757801242202), 'train_cv_std': np.float64(0.007165013437386577), 'train_cv_scores': array([0.82778071, 0.81070004, 0.81574659]), 'val_roc_auc': np.float64(0.805329455863447), 'feature_indices': array([105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,
#         10,   7])}, 17: {'train_cv_mean': np.float64(0.822536135208364), 'train_cv_std': np.float64(0.004692829179438587), 'train_cv_scores': array([0.82877675, 0.81746006, 0.8213716 ]), 'val_roc_auc': np.float64(0.8101981983295324), 'feature_indices': array([104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,
#         11,   8,  10,   7])}, 19: {'train_cv_mean': np.float64(0.8268566323293246), 'train_cv_std': np.float64(0.003612966502056144), 'train_cv_scores': array([0.83181472, 0.82330833, 0.82544684]), 'val_roc_auc': np.float64(0.8159728328065478), 'feature_indices': array([ 59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,
#         64,  87,  11,   8,  10,   7])}, 21: {'train_cv_mean': np.float64(0.8286092878089216), 'train_cv_std': np.float64(0.004371920650421734), 'train_cv_scores': array([0.83477917, 0.82587075, 0.82517795]), 'val_roc_auc': np.float64(0.8168746247279135), 'feature_indices': array([  5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,
#         18, 110,  64,  87,  11,   8,  10,   7])}, 23: {'train_cv_mean': np.float64(0.8312077356619042), 'train_cv_std': np.float64(0.00434579144459066), 'train_cv_scores': array([0.83732318, 0.82867903, 0.827621  ]), 'val_roc_auc': np.float64(0.8190010906238241), 'feature_indices': array([ 67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 25: {'train_cv_mean': np.float64(0.83142578603176), 'train_cv_std': np.float64(0.004395103495811635), 'train_cv_scores': array([0.83762612, 0.82870284, 0.8279484 ]), 'val_roc_auc': np.float64(0.8191603107685663), 'feature_indices': array([ 38, 107,  67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84,
#        112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 27: {'train_cv_mean': np.float64(0.8350132229384605), 'train_cv_std': np.float64(0.004210574817947165), 'train_cv_scores': array([0.8409671 , 0.83211972, 0.83195286]), 'val_roc_auc': np.float64(0.8223305911326906), 'feature_indices': array([ 12,  58,  38, 107,  67,  13,   5,  35,  59,  81, 104,  36, 105,
#         82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,
#          7])}, 29: {'train_cv_mean': np.float64(0.8351113952866367), 'train_cv_std': np.float64(0.004277845678072723), 'train_cv_scores': array([0.84116106, 0.83212042, 0.83205271]), 'val_roc_auc': np.float64(0.8225450485951727), 'feature_indices': array([113,  20,  12,  58,  38, 107,  67,  13,   5,  35,  59,  81, 104,
#         36, 105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,
#          8,  10,   7])}, 31: {'train_cv_mean': np.float64(0.8355501613148645), 'train_cv_std': np.float64(0.004068631275057966), 'train_cv_scores': array([0.84130402, 0.83265055, 0.83269592]), 'val_roc_auc': np.float64(0.8225756853755273), 'feature_indices': array([ 43,  90, 113,  20,  12,  58,  38, 107,  67,  13,   5,  35,  59,
#         81, 104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,  64,
#         87,  11,   8,  10,   7])}, 33: {'train_cv_mean': np.float64(0.8352596566267577), 'train_cv_std': np.float64(0.003670342459175291), 'train_cv_scores': array([0.84044985, 0.83272435, 0.83260478]), 'val_roc_auc': np.float64(0.8229052870199365), 'feature_indices': array([  6,  61,  43,  90, 113,  20,  12,  58,  38, 107,  67,  13,   5,
#         35,  59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,  18,
#        110,  64,  87,  11,   8,  10,   7])}, 35: {'train_cv_mean': np.float64(0.8355068667494971), 'train_cv_std': np.float64(0.0036042660299965873), 'train_cv_scores': array([0.84060144, 0.83310124, 0.83281792]), 'val_roc_auc': np.float64(0.8232143882165248), 'feature_indices': array([ 44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,  67,
#         13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,  41,
#         66,  18, 110,  64,  87,  11,   8,  10,   7])}, 37: {'train_cv_mean': np.float64(0.8355758574863463), 'train_cv_std': np.float64(0.0036400314033745405), 'train_cv_scores': array([0.8407222 , 0.83310821, 0.83289716]), 'val_roc_auc': np.float64(0.8232709922307859), 'feature_indices': array([ 69,   0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38,
#        107,  67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,
#         89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 39: {'train_cv_mean': np.float64(0.8357601291202359), 'train_cv_std': np.float64(0.003573719041945907), 'train_cv_scores': array([0.84081371, 0.83317657, 0.83329011]), 'val_roc_auc': np.float64(0.8234542434560294), 'feature_indices': array([ 21, 115,  69,   0,  44,  91,   6,  61,  43,  90, 113,  20,  12,
#         58,  38, 107,  67,  13,   5,  35,  59,  81, 104,  36, 105,  82,
#         84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 41: {'train_cv_mean': np.float64(0.8358880466037921), 'train_cv_std': np.float64(0.0034216983497171276), 'train_cv_scores': array([0.84072559, 0.83336598, 0.83357257]), 'val_roc_auc': np.float64(0.8234386403374101), 'feature_indices': array([ 92,  46,  21, 115,  69,   0,  44,  91,   6,  61,  43,  90, 113,
#         20,  12,  58,  38, 107,  67,  13,   5,  35,  59,  81, 104,  36,
#        105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,
#         10,   7])}, 43: {'train_cv_mean': np.float64(0.8379722441638072), 'train_cv_std': np.float64(0.003821019031202379), 'train_cv_scores': array([0.84336105, 0.8356255 , 0.83493018]), 'val_roc_auc': np.float64(0.8266783944413718), 'feature_indices': array([  4,  23,  92,  46,  21, 115,  69,   0,  44,  91,   6,  61,  43,
#         90, 113,  20,  12,  58,  38, 107,  67,  13,   5,  35,  59,  81,
#        104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,
#         11,   8,  10,   7])}, 45: {'train_cv_mean': np.float64(0.8378503128420663), 'train_cv_std': np.float64(0.003899085848557518), 'train_cv_scores': array([0.84332336, 0.83569572, 0.83453186]), 'val_roc_auc': np.float64(0.8266469604213798), 'feature_indices': array([  9,  68,   4,  23,  92,  46,  21, 115,  69,   0,  44,  91,   6,
#         61,  43,  90, 113,  20,  12,  58,  38, 107,  67,  13,   5,  35,
#         59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,
#         64,  87,  11,   8,  10,   7])}, 47: {'train_cv_mean': np.float64(0.8379567404993216), 'train_cv_std': np.float64(0.0038032542472707684), 'train_cv_scores': array([0.84329136, 0.83588397, 0.83469489]), 'val_roc_auc': np.float64(0.8269999097980296), 'feature_indices': array([114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,   0,  44,
#         91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,  67,  13,
#          5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,
#         18, 110,  64,  87,  11,   8,  10,   7])}, 49: {'train_cv_mean': np.float64(0.8378965939731771), 'train_cv_std': np.float64(0.0038435071154315496), 'train_cv_scores': array([0.84328912, 0.83579135, 0.83460931]), 'val_roc_auc': np.float64(0.8270155129166488), 'feature_indices': array([ 22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,
#          0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,
#         67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 51: {'train_cv_mean': np.float64(0.8379817377027944), 'train_cv_std': np.float64(0.0038579258811542857), 'train_cv_scores': array([0.84339509, 0.8358642 , 0.83468593]), 'val_roc_auc': np.float64(0.827116534567855), 'feature_indices': array([111,  45,  22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21,
#        115,  69,   0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,
#         38, 107,  67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84,
#        112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 53: {'train_cv_mean': np.float64(0.8379672288629144), 'train_cv_std': np.float64(0.0038828008930432436), 'train_cv_scores': array([0.84340456, 0.83591246, 0.83458466]), 'val_roc_auc': np.float64(0.827230881510145), 'feature_indices': array([ 76,  65, 111,  45,  22,  15, 114,  39,   9,  68,   4,  23,  92,
#         46,  21, 115,  69,   0,  44,  91,   6,  61,  43,  90, 113,  20,
#         12,  58,  38, 107,  67,  13,   5,  35,  59,  81, 104,  36, 105,
#         82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,
#          7])}, 55: {'train_cv_mean': np.float64(0.8377575836018103), 'train_cv_std': np.float64(0.0038254344442572065), 'train_cv_scores': array([0.84310713, 0.83578118, 0.83438445]), 'val_roc_auc': np.float64(0.827136009993285), 'feature_indices': array([122,  88,  76,  65, 111,  45,  22,  15, 114,  39,   9,  68,   4,
#         23,  92,  46,  21, 115,  69,   0,  44,  91,   6,  61,  43,  90,
#        113,  20,  12,  58,  38, 107,  67,  13,   5,  35,  59,  81, 104,
#         36, 105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,
#          8,  10,   7])}, 57: {'train_cv_mean': np.float64(0.8377259232035831), 'train_cv_std': np.float64(0.0038162773749440527), 'train_cv_scores': array([0.84307232, 0.8356915 , 0.83441396]), 'val_roc_auc': np.float64(0.827228262008479), 'feature_indices': array([ 53,  99, 122,  88,  76,  65, 111,  45,  22,  15, 114,  39,   9,
#         68,   4,  23,  92,  46,  21, 115,  69,   0,  44,  91,   6,  61,
#         43,  90, 113,  20,  12,  58,  38, 107,  67,  13,   5,  35,  59,
#         81, 104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,  64,
#         87,  11,   8,  10,   7])}, 59: {'train_cv_mean': np.float64(0.8377955355834948), 'train_cv_std': np.float64(0.0038337954859774073), 'train_cv_scores': array([0.84316376, 0.83576991, 0.83445294]), 'val_roc_auc': np.float64(0.8271279237055333), 'feature_indices': array([ 71,  16,  53,  99, 122,  88,  76,  65, 111,  45,  22,  15, 114,
#         39,   9,  68,   4,  23,  92,  46,  21, 115,  69,   0,  44,  91,
#          6,  61,  43,  90, 113,  20,  12,  58,  38, 107,  67,  13,   5,
#         35,  59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,  18,
#        110,  64,  87,  11,   8,  10,   7])}, 61: {'train_cv_mean': np.float64(0.8377673115728822), 'train_cv_std': np.float64(0.0038257513628668152), 'train_cv_scores': array([0.84312095, 0.83576761, 0.83441338]), 'val_roc_auc': np.float64(0.827140110082849), 'feature_indices': array([ 94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,  45,  22,
#         15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,   0,
#         44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,  67,
#         13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,  41,
#         66,  18, 110,  64,  87,  11,   8,  10,   7])}, 63: {'train_cv_mean': np.float64(0.8379551633758829), 'train_cv_std': np.float64(0.003820791549543185), 'train_cv_scores': array([0.84328579, 0.83605533, 0.83452437]), 'val_roc_auc': np.float64(0.8270492247641765), 'feature_indices': array([ 25,  63,  94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,
#         45,  22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,
#         69,   0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38,
#        107,  67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,
#         89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 65: {'train_cv_mean': np.float64(0.8379468065687529), 'train_cv_std': np.float64(0.003770571636611762), 'train_cv_scores': array([0.84320388, 0.83609168, 0.83454485]), 'val_roc_auc': np.float64(0.8270207519199808), 'feature_indices': array([ 48, 117,  25,  63,  94,  30,  71,  16,  53,  99, 122,  88,  76,
#         65, 111,  45,  22,  15, 114,  39,   9,  68,   4,  23,  92,  46,
#         21, 115,  69,   0,  44,  91,   6,  61,  43,  90, 113,  20,  12,
#         58,  38, 107,  67,  13,   5,  35,  59,  81, 104,  36, 105,  82,
#         84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 67: {'train_cv_mean': np.float64(0.8379336026957969), 'train_cv_std': np.float64(0.0037458819610123135), 'train_cv_scores': array([0.84316242, 0.83605546, 0.83458294]), 'val_roc_auc': np.float64(0.8272142533691347), 'feature_indices': array([109,  19,  48, 117,  25,  63,  94,  30,  71,  16,  53,  99, 122,
#         88,  76,  65, 111,  45,  22,  15, 114,  39,   9,  68,   4,  23,
#         92,  46,  21, 115,  69,   0,  44,  91,   6,  61,  43,  90, 113,
#         20,  12,  58,  38, 107,  67,  13,   5,  35,  59,  81, 104,  36,
#        105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,
#         10,   7])}, 69: {'train_cv_mean': np.float64(0.8380210968005364), 'train_cv_std': np.float64(0.00373066585613011), 'train_cv_scores': array([0.84322826, 0.83615294, 0.83468208]), 'val_roc_auc': np.float64(0.8273546814367078), 'feature_indices': array([ 86,  42, 109,  19,  48, 117,  25,  63,  94,  30,  71,  16,  53,
#         99, 122,  88,  76,  65, 111,  45,  22,  15, 114,  39,   9,  68,
#          4,  23,  92,  46,  21, 115,  69,   0,  44,  91,   6,  61,  43,
#         90, 113,  20,  12,  58,  38, 107,  67,  13,   5,  35,  59,  81,
#        104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,
#         11,   8,  10,   7])}, 71: {'train_cv_mean': np.float64(0.8378161356787407), 'train_cv_std': np.float64(0.0037610056047792865), 'train_cv_scores': array([0.84305113, 0.8360134 , 0.83438387]), 'val_roc_auc': np.float64(0.8272845243486096), 'feature_indices': array([ 62,  83,  86,  42, 109,  19,  48, 117,  25,  63,  94,  30,  71,
#         16,  53,  99, 122,  88,  76,  65, 111,  45,  22,  15, 114,  39,
#          9,  68,   4,  23,  92,  46,  21, 115,  69,   0,  44,  91,   6,
#         61,  43,  90, 113,  20,  12,  58,  38, 107,  67,  13,   5,  35,
#         59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,
#         64,  87,  11,   8,  10,   7])}, 73: {'train_cv_mean': np.float64(0.8383650278135261), 'train_cv_std': np.float64(0.0036341833708318093), 'train_cv_scores': array([0.84335478, 0.8369368 , 0.83480351]), 'val_roc_auc': np.float64(0.8279465749218476), 'feature_indices': array([ 40,  70,  62,  83,  86,  42, 109,  19,  48, 117,  25,  63,  94,
#         30,  71,  16,  53,  99, 122,  88,  76,  65, 111,  45,  22,  15,
#        114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,   0,  44,
#         91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,  67,  13,
#          5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,
#         18, 110,  64,  87,  11,   8,  10,   7])}, 75: {'train_cv_mean': np.float64(0.8384988669449323), 'train_cv_std': np.float64(0.003488988578131113), 'train_cv_scores': array([0.8433581 , 0.83681115, 0.83532735]), 'val_roc_auc': np.float64(0.8278503367084664), 'feature_indices': array([ 51,  17,  40,  70,  62,  83,  86,  42, 109,  19,  48, 117,  25,
#         63,  94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,  45,
#         22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,
#          0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,
#         67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 77: {'train_cv_mean': np.float64(0.8385187269970814), 'train_cv_std': np.float64(0.003533488059388584), 'train_cv_scores': array([0.84341544, 0.83693347, 0.83520727]), 'val_roc_auc': np.float64(0.8279968010190089), 'feature_indices': array([116,  93,  51,  17,  40,  70,  62,  83,  86,  42, 109,  19,  48,
#        117,  25,  63,  94,  30,  71,  16,  53,  99, 122,  88,  76,  65,
#        111,  45,  22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21,
#        115,  69,   0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,
#         38, 107,  67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84,
#        112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 79: {'train_cv_mean': np.float64(0.8384095791716749), 'train_cv_std': np.float64(0.0035539295457416133), 'train_cv_scores': array([0.84332419, 0.83686364, 0.83504091]), 'val_roc_auc': np.float64(0.8279737949608987), 'feature_indices': array([ 28, 108, 116,  93,  51,  17,  40,  70,  62,  83,  86,  42, 109,
#         19,  48, 117,  25,  63,  94,  30,  71,  16,  53,  99, 122,  88,
#         76,  65, 111,  45,  22,  15, 114,  39,   9,  68,   4,  23,  92,
#         46,  21, 115,  69,   0,  44,  91,   6,  61,  43,  90, 113,  20,
#         12,  58,  38, 107,  67,  13,   5,  35,  59,  81, 104,  36, 105,
#         82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,
#          7])}, 81: {'train_cv_mean': np.float64(0.8383485100625702), 'train_cv_std': np.float64(0.003640344282291235), 'train_cv_scores': array([0.84338434, 0.83675712, 0.83490406]), 'val_roc_auc': np.float64(0.8279063712658434), 'feature_indices': array([ 74, 120,  28, 108, 116,  93,  51,  17,  40,  70,  62,  83,  86,
#         42, 109,  19,  48, 117,  25,  63,  94,  30,  71,  16,  53,  99,
#        122,  88,  76,  65, 111,  45,  22,  15, 114,  39,   9,  68,   4,
#         23,  92,  46,  21, 115,  69,   0,  44,  91,   6,  61,  43,  90,
#        113,  20,  12,  58,  38, 107,  67,  13,   5,  35,  59,  81, 104,
#         36, 105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,
#          8,  10,   7])}, 83: {'train_cv_mean': np.float64(0.8382179369786694), 'train_cv_std': np.float64(0.0036846460475495756), 'train_cv_scores': array([0.84332886, 0.83654212, 0.83478283]), 'val_roc_auc': np.float64(0.8278309751744133), 'feature_indices': array([ 97,  85,  74, 120,  28, 108, 116,  93,  51,  17,  40,  70,  62,
#         83,  86,  42, 109,  19,  48, 117,  25,  63,  94,  30,  71,  16,
#         53,  99, 122,  88,  76,  65, 111,  45,  22,  15, 114,  39,   9,
#         68,   4,  23,  92,  46,  21, 115,  69,   0,  44,  91,   6,  61,
#         43,  90, 113,  20,  12,  58,  38, 107,  67,  13,   5,  35,  59,
#         81, 104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,  64,
#         87,  11,   8,  10,   7])}, 85: {'train_cv_mean': np.float64(0.8382588492084325), 'train_cv_std': np.float64(0.0037226452311751763), 'train_cv_scores': array([0.84344533, 0.83644822, 0.83488301]), 'val_roc_auc': np.float64(0.8277859880805841), 'feature_indices': array([106,  60,  97,  85,  74, 120,  28, 108, 116,  93,  51,  17,  40,
#         70,  62,  83,  86,  42, 109,  19,  48, 117,  25,  63,  94,  30,
#         71,  16,  53,  99, 122,  88,  76,  65, 111,  45,  22,  15, 114,
#         39,   9,  68,   4,  23,  92,  46,  21, 115,  69,   0,  44,  91,
#          6,  61,  43,  90, 113,  20,  12,  58,  38, 107,  67,  13,   5,
#         35,  59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,  18,
#        110,  64,  87,  11,   8,  10,   7])}, 87: {'train_cv_mean': np.float64(0.8386005315009362), 'train_cv_std': np.float64(0.003965088337114611), 'train_cv_scores': array([0.84414335, 0.83656446, 0.83509378]), 'val_roc_auc': np.float64(0.8279909925587932), 'feature_indices': array([ 14,  24, 106,  60,  97,  85,  74, 120,  28, 108, 116,  93,  51,
#         17,  40,  70,  62,  83,  86,  42, 109,  19,  48, 117,  25,  63,
#         94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,  45,  22,
#         15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,   0,
#         44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,  67,
#         13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,  41,
#         66,  18, 110,  64,  87,  11,   8,  10,   7])}, 89: {'train_cv_mean': np.float64(0.8389293551874845), 'train_cv_std': np.float64(0.003924991296490205), 'train_cv_scores': array([0.84446959, 0.83645538, 0.83586309]), 'val_roc_auc': np.float64(0.8281016949770258), 'feature_indices': array([ 47,  37,  14,  24, 106,  60,  97,  85,  74, 120,  28, 108, 116,
#         93,  51,  17,  40,  70,  62,  83,  86,  42, 109,  19,  48, 117,
#         25,  63,  94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,
#         45,  22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,
#         69,   0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38,
#        107,  67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,
#         89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7]), 'train_cv_mean_optimized': np.float64(0.8393412410916516), 'train_cv_std_optimized': np.float64(0.0037163542291336095), 'train_cv_scores_optimized': array([0.84458138, 0.83707135, 0.83637099]), 'val_roc_auc_optimized': np.float64(0.8286671656627521), 'best_params': {'solver': 'liblinear', 'penalty': 'l1', 'max_iter': 1000, 'class_weight': 'balanced', 'C': 0.1}, 'best_model': LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000, penalty='l1',
#                    solver='liblinear'), 'hyperparameter_cv_score': np.float64(0.8393545512232349)}, 91: {'train_cv_mean': np.float64(0.8388968312124258), 'train_cv_std': np.float64(0.004007514616904678), 'train_cv_scores': array([0.84455655, 0.83632372, 0.83581022]), 'val_roc_auc': np.float64(0.8279990788465448), 'feature_indices': array([125,   3,  47,  37,  14,  24, 106,  60,  97,  85,  74, 120,  28,
#        108, 116,  93,  51,  17,  40,  70,  62,  83,  86,  42, 109,  19,
#         48, 117,  25,  63,  94,  30,  71,  16,  53,  99, 122,  88,  76,
#         65, 111,  45,  22,  15, 114,  39,   9,  68,   4,  23,  92,  46,
#         21, 115,  69,   0,  44,  91,   6,  61,  43,  90, 113,  20,  12,
#         58,  38, 107,  67,  13,   5,  35,  59,  81, 104,  36, 105,  82,
#         84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 93: {'train_cv_mean': np.float64(0.8388528565864662), 'train_cv_std': np.float64(0.004040698444066263), 'train_cv_scores': array([0.84456186, 0.83621349, 0.83578321]), 'val_roc_auc': np.float64(0.8278900847989635), 'feature_indices': array([102,  79, 125,   3,  47,  37,  14,  24, 106,  60,  97,  85,  74,
#        120,  28, 108, 116,  93,  51,  17,  40,  70,  62,  83,  86,  42,
#        109,  19,  48, 117,  25,  63,  94,  30,  71,  16,  53,  99, 122,
#         88,  76,  65, 111,  45,  22,  15, 114,  39,   9,  68,   4,  23,
#         92,  46,  21, 115,  69,   0,  44,  91,   6,  61,  43,  90, 113,
#         20,  12,  58,  38, 107,  67,  13,   5,  35,  59,  81, 104,  36,
#        105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,
#         10,   7])}, 95: {'train_cv_mean': np.float64(0.8387494879830971), 'train_cv_std': np.float64(0.004094562275259801), 'train_cv_scores': array([0.84451918, 0.83629024, 0.83543904]), 'val_roc_auc': np.float64(0.8278337085674561), 'feature_indices': array([ 33,  56, 102,  79, 125,   3,  47,  37,  14,  24, 106,  60,  97,
#         85,  74, 120,  28, 108, 116,  93,  51,  17,  40,  70,  62,  83,
#         86,  42, 109,  19,  48, 117,  25,  63,  94,  30,  71,  16,  53,
#         99, 122,  88,  76,  65, 111,  45,  22,  15, 114,  39,   9,  68,
#          4,  23,  92,  46,  21, 115,  69,   0,  44,  91,   6,  61,  43,
#         90, 113,  20,  12,  58,  38, 107,  67,  13,   5,  35,  59,  81,
#        104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,
#         11,   8,  10,   7])}, 97: {'train_cv_mean': np.float64(0.838738119296598), 'train_cv_std': np.float64(0.004072655724696336), 'train_cv_scores': array([0.84447727, 0.83628858, 0.83544851]), 'val_roc_auc': np.float64(0.8278175359919528), 'feature_indices': array([ 80,  72,  33,  56, 102,  79, 125,   3,  47,  37,  14,  24, 106,
#         60,  97,  85,  74, 120,  28, 108, 116,  93,  51,  17,  40,  70,
#         62,  83,  86,  42, 109,  19,  48, 117,  25,  63,  94,  30,  71,
#         16,  53,  99, 122,  88,  76,  65, 111,  45,  22,  15, 114,  39,
#          9,  68,   4,  23,  92,  46,  21, 115,  69,   0,  44,  91,   6,
#         61,  43,  90, 113,  20,  12,  58,  38, 107,  67,  13,   5,  35,
#         59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,
#         64,  87,  11,   8,  10,   7])}, 99: {'train_cv_mean': np.float64(0.8386965463060024), 'train_cv_std': np.float64(0.004000953636282453), 'train_cv_scores': array([0.84433924, 0.83623782, 0.83551259]), 'val_roc_auc': np.float64(0.8277248284112517), 'feature_indices': array([ 95,  49,  80,  72,  33,  56, 102,  79, 125,   3,  47,  37,  14,
#         24, 106,  60,  97,  85,  74, 120,  28, 108, 116,  93,  51,  17,
#         40,  70,  62,  83,  86,  42, 109,  19,  48, 117,  25,  63,  94,
#         30,  71,  16,  53,  99, 122,  88,  76,  65, 111,  45,  22,  15,
#        114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,   0,  44,
#         91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,  67,  13,
#          5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,
#         18, 110,  64,  87,  11,   8,  10,   7])}, 101: {'train_cv_mean': np.float64(0.8386646544249583), 'train_cv_std': np.float64(0.003977325688729855), 'train_cv_scores': array([0.84427275, 0.83623564, 0.83548557]), 'val_roc_auc': np.float64(0.827762982022474), 'feature_indices': array([103,  57,  95,  49,  80,  72,  33,  56, 102,  79, 125,   3,  47,
#         37,  14,  24, 106,  60,  97,  85,  74, 120,  28, 108, 116,  93,
#         51,  17,  40,  70,  62,  83,  86,  42, 109,  19,  48, 117,  25,
#         63,  94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,  45,
#         22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,
#          0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,
#         67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 103: {'train_cv_mean': np.float64(0.8386312635571925), 'train_cv_std': np.float64(0.004004767848818112), 'train_cv_scores': array([0.8442739 , 0.83623154, 0.83538835]), 'val_roc_auc': np.float64(0.8278040968094924), 'feature_indices': array([126, 118, 103,  57,  95,  49,  80,  72,  33,  56, 102,  79, 125,
#          3,  47,  37,  14,  24, 106,  60,  97,  85,  74, 120,  28, 108,
#        116,  93,  51,  17,  40,  70,  62,  83,  86,  42, 109,  19,  48,
#        117,  25,  63,  94,  30,  71,  16,  53,  99, 122,  88,  76,  65,
#        111,  45,  22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21,
#        115,  69,   0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,
#         38, 107,  67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84,
#        112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 105: {'train_cv_mean': np.float64(0.8385742644655526), 'train_cv_std': np.float64(0.004105809886301163), 'train_cv_scores': array([0.84437558, 0.83588583, 0.83546138]), 'val_roc_auc': np.float64(0.8276210733670026), 'feature_indices': array([ 26,  34, 126, 118, 103,  57,  95,  49,  80,  72,  33,  56, 102,
#         79, 125,   3,  47,  37,  14,  24, 106,  60,  97,  85,  74, 120,
#         28, 108, 116,  93,  51,  17,  40,  70,  62,  83,  86,  42, 109,
#         19,  48, 117,  25,  63,  94,  30,  71,  16,  53,  99, 122,  88,
#         76,  65, 111,  45,  22,  15, 114,  39,   9,  68,   4,  23,  92,
#         46,  21, 115,  69,   0,  44,  91,   6,  61,  43,  90, 113,  20,
#         12,  58,  38, 107,  67,  13,   5,  35,  59,  81, 104,  36, 105,
#         82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,
#          7])}, 107: {'train_cv_mean': np.float64(0.8385597662630424), 'train_cv_std': np.float64(0.004026271756990725), 'train_cv_scores': array([0.84424984, 0.83589806, 0.8355314 ]), 'val_roc_auc': np.float64(0.8277579708018956), 'feature_indices': array([ 77, 100,  26,  34, 126, 118, 103,  57,  95,  49,  80,  72,  33,
#         56, 102,  79, 125,   3,  47,  37,  14,  24, 106,  60,  97,  85,
#         74, 120,  28, 108, 116,  93,  51,  17,  40,  70,  62,  83,  86,
#         42, 109,  19,  48, 117,  25,  63,  94,  30,  71,  16,  53,  99,
#        122,  88,  76,  65, 111,  45,  22,  15, 114,  39,   9,  68,   4,
#         23,  92,  46,  21, 115,  69,   0,  44,  91,   6,  61,  43,  90,
#        113,  20,  12,  58,  38, 107,  67,  13,   5,  35,  59,  81, 104,
#         36, 105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,
#          8,  10,   7])}, 109: {'train_cv_mean': np.float64(0.8385960523935041), 'train_cv_std': np.float64(0.004052746086719817), 'train_cv_scores': array([0.84432529, 0.83586944, 0.83559343]), 'val_roc_auc': np.float64(0.8278720899614318), 'feature_indices': array([ 73, 123,  77, 100,  26,  34, 126, 118, 103,  57,  95,  49,  80,
#         72,  33,  56, 102,  79, 125,   3,  47,  37,  14,  24, 106,  60,
#         97,  85,  74, 120,  28, 108, 116,  93,  51,  17,  40,  70,  62,
#         83,  86,  42, 109,  19,  48, 117,  25,  63,  94,  30,  71,  16,
#         53,  99, 122,  88,  76,  65, 111,  45,  22,  15, 114,  39,   9,
#         68,   4,  23,  92,  46,  21, 115,  69,   0,  44,  91,   6,  61,
#         43,  90, 113,  20,  12,  58,  38, 107,  67,  13,   5,  35,  59,
#         81, 104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,  64,
#         87,  11,   8,  10,   7])}, 111: {'train_cv_mean': np.float64(0.838730118624297), 'train_cv_std': np.float64(0.004051033181781325), 'train_cv_scores': array([0.84445397, 0.83607895, 0.83565744]), 'val_roc_auc': np.float64(0.8278407698328165), 'feature_indices': array([  1,  50,  73, 123,  77, 100,  26,  34, 126, 118, 103,  57,  95,
#         49,  80,  72,  33,  56, 102,  79, 125,   3,  47,  37,  14,  24,
#        106,  60,  97,  85,  74, 120,  28, 108, 116,  93,  51,  17,  40,
#         70,  62,  83,  86,  42, 109,  19,  48, 117,  25,  63,  94,  30,
#         71,  16,  53,  99, 122,  88,  76,  65, 111,  45,  22,  15, 114,
#         39,   9,  68,   4,  23,  92,  46,  21, 115,  69,   0,  44,  91,
#          6,  61,  43,  90, 113,  20,  12,  58,  38, 107,  67,  13,   5,
#         35,  59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,  18,
#        110,  64,  87,  11,   8,  10,   7])}, 113: {'train_cv_mean': np.float64(0.8386342092326714), 'train_cv_std': np.float64(0.003975369012693146), 'train_cv_scores': array([0.84424657, 0.83611326, 0.8355428 ]), 'val_roc_auc': np.float64(0.828057049557327), 'feature_indices': array([119,  54,   1,  50,  73, 123,  77, 100,  26,  34, 126, 118, 103,
#         57,  95,  49,  80,  72,  33,  56, 102,  79, 125,   3,  47,  37,
#         14,  24, 106,  60,  97,  85,  74, 120,  28, 108, 116,  93,  51,
#         17,  40,  70,  62,  83,  86,  42, 109,  19,  48, 117,  25,  63,
#         94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,  45,  22,
#         15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,   0,
#         44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,  67,
#         13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,  41,
#         66,  18, 110,  64,  87,  11,   8,  10,   7])}, 115: {'train_cv_mean': np.float64(0.8386616033374704), 'train_cv_std': np.float64(0.004120482669709738), 'train_cv_scores': array([0.84448866, 0.8357075 , 0.83578865]), 'val_roc_auc': np.float64(0.828261484578652), 'feature_indices': array([ 31,  96, 119,  54,   1,  50,  73, 123,  77, 100,  26,  34, 126,
#        118, 103,  57,  95,  49,  80,  72,  33,  56, 102,  79, 125,   3,
#         47,  37,  14,  24, 106,  60,  97,  85,  74, 120,  28, 108, 116,
#         93,  51,  17,  40,  70,  62,  83,  86,  42, 109,  19,  48, 117,
#         25,  63,  94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,
#         45,  22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,
#         69,   0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38,
#        107,  67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,
#         89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 117: {'train_cv_mean': np.float64(0.8385800031920395), 'train_cv_std': np.float64(0.0040851609505369695), 'train_cv_scores': array([0.84435613, 0.83559152, 0.83579236]), 'val_roc_auc': np.float64(0.8282523732685095), 'feature_indices': array([121,  27,  31,  96, 119,  54,   1,  50,  73, 123,  77, 100,  26,
#         34, 126, 118, 103,  57,  95,  49,  80,  72,  33,  56, 102,  79,
#        125,   3,  47,  37,  14,  24, 106,  60,  97,  85,  74, 120,  28,
#        108, 116,  93,  51,  17,  40,  70,  62,  83,  86,  42, 109,  19,
#         48, 117,  25,  63,  94,  30,  71,  16,  53,  99, 122,  88,  76,
#         65, 111,  45,  22,  15, 114,  39,   9,  68,   4,  23,  92,  46,
#         21, 115,  69,   0,  44,  91,   6,  61,  43,  90, 113,  20,  12,
#         58,  38, 107,  67,  13,   5,  35,  59,  81, 104,  36, 105,  82,
#         84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 119: {'train_cv_mean': np.float64(0.8385897990194797), 'train_cv_std': np.float64(0.004061210054805324), 'train_cv_scores': array([0.84433316, 0.83569515, 0.83574109]), 'val_roc_auc': np.float64(0.828266268016477), 'feature_indices': array([ 98,  52, 121,  27,  31,  96, 119,  54,   1,  50,  73, 123,  77,
#        100,  26,  34, 126, 118, 103,  57,  95,  49,  80,  72,  33,  56,
#        102,  79, 125,   3,  47,  37,  14,  24, 106,  60,  97,  85,  74,
#        120,  28, 108, 116,  93,  51,  17,  40,  70,  62,  83,  86,  42,
#        109,  19,  48, 117,  25,  63,  94,  30,  71,  16,  53,  99, 122,
#         88,  76,  65, 111,  45,  22,  15, 114,  39,   9,  68,   4,  23,
#         92,  46,  21, 115,  69,   0,  44,  91,   6,  61,  43,  90, 113,
#         20,  12,  58,  38, 107,  67,  13,   5,  35,  59,  81, 104,  36,
#        105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,
#         10,   7])}, 121: {'train_cv_mean': np.float64(0.8385364369906462), 'train_cv_std': np.float64(0.0041014959028361836), 'train_cv_scores': array([0.8443368 , 0.83562166, 0.83565084]), 'val_roc_auc': np.float64(0.8283169496791453), 'feature_indices': array([ 29,  75,  98,  52, 121,  27,  31,  96, 119,  54,   1,  50,  73,
#        123,  77, 100,  26,  34, 126, 118, 103,  57,  95,  49,  80,  72,
#         33,  56, 102,  79, 125,   3,  47,  37,  14,  24, 106,  60,  97,
#         85,  74, 120,  28, 108, 116,  93,  51,  17,  40,  70,  62,  83,
#         86,  42, 109,  19,  48, 117,  25,  63,  94,  30,  71,  16,  53,
#         99, 122,  88,  76,  65, 111,  45,  22,  15, 114,  39,   9,  68,
#          4,  23,  92,  46,  21, 115,  69,   0,  44,  91,   6,  61,  43,
#         90, 113,  20,  12,  58,  38, 107,  67,  13,   5,  35,  59,  81,
#        104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,
#         11,   8,  10,   7])}, 123: {'train_cv_mean': np.float64(0.838531675701752), 'train_cv_std': np.float64(0.004133806023443441), 'train_cv_scores': array([0.84437776, 0.83561225, 0.83560501]), 'val_roc_auc': np.float64(0.8282391618688025), 'feature_indices': array([ 78,   2,  29,  75,  98,  52, 121,  27,  31,  96, 119,  54,   1,
#         50,  73, 123,  77, 100,  26,  34, 126, 118, 103,  57,  95,  49,
#         80,  72,  33,  56, 102,  79, 125,   3,  47,  37,  14,  24, 106,
#         60,  97,  85,  74, 120,  28, 108, 116,  93,  51,  17,  40,  70,
#         62,  83,  86,  42, 109,  19,  48, 117,  25,  63,  94,  30,  71,
#         16,  53,  99, 122,  88,  76,  65, 111,  45,  22,  15, 114,  39,
#          9,  68,   4,  23,  92,  46,  21, 115,  69,   0,  44,  91,   6,
#         61,  43,  90, 113,  20,  12,  58,  38, 107,  67,  13,   5,  35,
#         59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,  18, 110,
#         64,  87,  11,   8,  10,   7])}, 125: {'train_cv_mean': np.float64(0.8384800258530785), 'train_cv_std': np.float64(0.00413034912808895), 'train_cv_scores': array([0.84432106, 0.83559696, 0.83552206]), 'val_roc_auc': np.float64(0.8282690014095198), 'feature_indices': array([124,  55,  78,   2,  29,  75,  98,  52, 121,  27,  31,  96, 119,
#         54,   1,  50,  73, 123,  77, 100,  26,  34, 126, 118, 103,  57,
#         95,  49,  80,  72,  33,  56, 102,  79, 125,   3,  47,  37,  14,
#         24, 106,  60,  97,  85,  74, 120,  28, 108, 116,  93,  51,  17,
#         40,  70,  62,  83,  86,  42, 109,  19,  48, 117,  25,  63,  94,
#         30,  71,  16,  53,  99, 122,  88,  76,  65, 111,  45,  22,  15,
#        114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,   0,  44,
#         91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,  67,  13,
#          5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,  41,  66,
#         18, 110,  64,  87,  11,   8,  10,   7])}, 127: {'train_cv_mean': np.float64(0.8383887579160899), 'train_cv_std': np.float64(0.004129331763778276), 'train_cv_scores': array([0.8442277 , 0.83555394, 0.83538463]), 'val_roc_auc': np.float64(0.8282228754019227), 'feature_indices': array([ 32, 101, 124,  55,  78,   2,  29,  75,  98,  52, 121,  27,  31,
#         96, 119,  54,   1,  50,  73, 123,  77, 100,  26,  34, 126, 118,
#        103,  57,  95,  49,  80,  72,  33,  56, 102,  79, 125,   3,  47,
#         37,  14,  24, 106,  60,  97,  85,  74, 120,  28, 108, 116,  93,
#         51,  17,  40,  70,  62,  83,  86,  42, 109,  19,  48, 117,  25,
#         63,  94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,  45,
#         22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,
#          0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,
#         67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 129: {'train_cv_mean': np.float64(0.8383887579160899), 'train_cv_std': np.float64(0.004129331763778276), 'train_cv_scores': array([0.8442277 , 0.83555394, 0.83538463]), 'val_roc_auc': np.float64(0.8282228754019227), 'feature_indices': array([ 32, 101, 124,  55,  78,   2,  29,  75,  98,  52, 121,  27,  31,
#         96, 119,  54,   1,  50,  73, 123,  77, 100,  26,  34, 126, 118,
#        103,  57,  95,  49,  80,  72,  33,  56, 102,  79, 125,   3,  47,
#         37,  14,  24, 106,  60,  97,  85,  74, 120,  28, 108, 116,  93,
#         51,  17,  40,  70,  62,  83,  86,  42, 109,  19,  48, 117,  25,
#         63,  94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,  45,
#         22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,
#          0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,
#         67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 131: {'train_cv_mean': np.float64(0.8383887579160899), 'train_cv_std': np.float64(0.004129331763778276), 'train_cv_scores': array([0.8442277 , 0.83555394, 0.83538463]), 'val_roc_auc': np.float64(0.8282228754019227), 'feature_indices': array([ 32, 101, 124,  55,  78,   2,  29,  75,  98,  52, 121,  27,  31,
#         96, 119,  54,   1,  50,  73, 123,  77, 100,  26,  34, 126, 118,
#        103,  57,  95,  49,  80,  72,  33,  56, 102,  79, 125,   3,  47,
#         37,  14,  24, 106,  60,  97,  85,  74, 120,  28, 108, 116,  93,
#         51,  17,  40,  70,  62,  83,  86,  42, 109,  19,  48, 117,  25,
#         63,  94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,  45,
#         22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,
#          0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,
#         67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 133: {'train_cv_mean': np.float64(0.8383887579160899), 'train_cv_std': np.float64(0.004129331763778276), 'train_cv_scores': array([0.8442277 , 0.83555394, 0.83538463]), 'val_roc_auc': np.float64(0.8282228754019227), 'feature_indices': array([ 32, 101, 124,  55,  78,   2,  29,  75,  98,  52, 121,  27,  31,
#         96, 119,  54,   1,  50,  73, 123,  77, 100,  26,  34, 126, 118,
#        103,  57,  95,  49,  80,  72,  33,  56, 102,  79, 125,   3,  47,
#         37,  14,  24, 106,  60,  97,  85,  74, 120,  28, 108, 116,  93,
#         51,  17,  40,  70,  62,  83,  86,  42, 109,  19,  48, 117,  25,
#         63,  94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,  45,
#         22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,
#          0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,
#         67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 135: {'train_cv_mean': np.float64(0.8383887579160899), 'train_cv_std': np.float64(0.004129331763778276), 'train_cv_scores': array([0.8442277 , 0.83555394, 0.83538463]), 'val_roc_auc': np.float64(0.8282228754019227), 'feature_indices': array([ 32, 101, 124,  55,  78,   2,  29,  75,  98,  52, 121,  27,  31,
#         96, 119,  54,   1,  50,  73, 123,  77, 100,  26,  34, 126, 118,
#        103,  57,  95,  49,  80,  72,  33,  56, 102,  79, 125,   3,  47,
#         37,  14,  24, 106,  60,  97,  85,  74, 120,  28, 108, 116,  93,
#         51,  17,  40,  70,  62,  83,  86,  42, 109,  19,  48, 117,  25,
#         63,  94,  30,  71,  16,  53,  99, 122,  88,  76,  65, 111,  45,
#         22,  15, 114,  39,   9,  68,   4,  23,  92,  46,  21, 115,  69,
#          0,  44,  91,   6,  61,  43,  90, 113,  20,  12,  58,  38, 107,
#         67,  13,   5,  35,  59,  81, 104,  36, 105,  82,  84, 112,  89,
# ...
#         89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 117: {'train_cv_mean': np.float64(0.838587384289004), 'train_cv_std': np.float64(0.0040926773909781946), 'train_cv_scores': array([0.84437501, 0.83564279, 0.83574436]), 'val_roc_auc': np.float64(0.8282235587501834), 'feature_indices': array([121,  27,  31,  54, 119,  96,   1,  50,  73, 123,  77,  26, 100,
#        103, 118, 126,  34,  49,  80,  95,  57,  72,  33,  56,  79, 102,
#        125,   3,  14,  37,  47,  24, 106,  60,  97,  85,  74, 120,  28,
#        108,  93, 116,  51,  83,  17,  70,  40,  62,  86,  42, 109,  19,
#        117,  48,  63,  94,  30,  71,  25, 122,  53,  16,  99,  88,  76,
#         65, 111,  22,  45,  15, 114,  39,  68,  23,   4,   9, 115,  46,
#         92,  21,  69,  91,   0,   6,  44,  61,  43,  90, 113,  12,  20,
#         38,  58,  13, 107,  35,   5,  67,  81,  59, 105, 104,  36,  82,
#         84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 119: {'train_cv_mean': np.float64(0.8385785972358143), 'train_cv_std': np.float64(0.004073948763319057), 'train_cv_scores': array([0.84434   , 0.83571333, 0.83568246]), 'val_roc_auc': np.float64(0.8282362006930063), 'feature_indices': array([ 98,  52, 121,  27,  31,  54, 119,  96,   1,  50,  73, 123,  77,
#         26, 100, 103, 118, 126,  34,  49,  80,  95,  57,  72,  33,  56,
#         79, 102, 125,   3,  14,  37,  47,  24, 106,  60,  97,  85,  74,
#        120,  28, 108,  93, 116,  51,  83,  17,  70,  40,  62,  86,  42,
#        109,  19, 117,  48,  63,  94,  30,  71,  25, 122,  53,  16,  99,
#         88,  76,  65, 111,  22,  45,  15, 114,  39,  68,  23,   4,   9,
#        115,  46,  92,  21,  69,  91,   0,   6,  44,  61,  43,  90, 113,
#         12,  20,  38,  58,  13, 107,  35,   5,  67,  81,  59, 105, 104,
#         36,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,  11,   8,
#         10,   7])}, 121: {'train_cv_mean': np.float64(0.8384998904704487), 'train_cv_std': np.float64(0.004109045714395667), 'train_cv_scores': array([0.84431095, 0.83560265, 0.83558607]), 'val_roc_auc': np.float64(0.8282135363090265), 'feature_indices': array([ 75,  29,  98,  52, 121,  27,  31,  54, 119,  96,   1,  50,  73,
#        123,  77,  26, 100, 103, 118, 126,  34,  49,  80,  95,  57,  72,
#         33,  56,  79, 102, 125,   3,  14,  37,  47,  24, 106,  60,  97,
#         85,  74, 120,  28, 108,  93, 116,  51,  83,  17,  70,  40,  62,
#         86,  42, 109,  19, 117,  48,  63,  94,  30,  71,  25, 122,  53,
#         16,  99,  88,  76,  65, 111,  22,  45,  15, 114,  39,  68,  23,
#          4,   9, 115,  46,  92,  21,  69,  91,   0,   6,  44,  61,  43,
#         90, 113,  12,  20,  38,  58,  13, 107,  35,   5,  67,  81,  59,
#        105, 104,  36,  82,  84, 112,  89,  41,  66,  18, 110,  64,  87,
#         11,   8,  10,   7])}, 123: {'train_cv_mean': np.float64(0.8384876209965234), 'train_cv_std': np.float64(0.004128434440269056), 'train_cv_scores': array([0.84432605, 0.83559056, 0.83554625]), 'val_roc_auc': np.float64(0.8282167252675763), 'feature_indices': array([ 55,   2,  75,  29,  98,  52, 121,  27,  31,  54, 119,  96,   1,
#         50,  73, 123,  77,  26, 100, 103, 118, 126,  34,  49,  80,  95,
#         57,  72,  33,  56,  79, 102, 125,   3,  14,  37,  47,  24, 106,
#         60,  97,  85,  74, 120,  28, 108,  93, 116,  51,  83,  17,  70,
#         40,  62,  86,  42, 109,  19, 117,  48,  63,  94,  30,  71,  25,
#        122,  53,  16,  99,  88,  76,  65, 111,  22,  45,  15, 114,  39,
#         68,  23,   4,   9, 115,  46,  92,  21,  69,  91,   0,   6,  44,
#         61,  43,  90, 113,  12,  20,  38,  58,  13, 107,  35,   5,  67,
#         81,  59, 105, 104,  36,  82,  84, 112,  89,  41,  66,  18, 110,
#         64,  87,  11,   8,  10,   7])}, 125: {'train_cv_mean': np.float64(0.8384615282172065), 'train_cv_std': np.float64(0.004137263788575364), 'train_cv_scores': array([0.84431223, 0.83558505, 0.8354873 ]), 'val_roc_auc': np.float64(0.8282434897411204), 'feature_indices': array([124,  78,  55,   2,  75,  29,  98,  52, 121,  27,  31,  54, 119,
#         96,   1,  50,  73, 123,  77,  26, 100, 103, 118, 126,  34,  49,
#         80,  95,  57,  72,  33,  56,  79, 102, 125,   3,  14,  37,  47,
#         24, 106,  60,  97,  85,  74, 120,  28, 108,  93, 116,  51,  83,
#         17,  70,  40,  62,  86,  42, 109,  19, 117,  48,  63,  94,  30,
#         71,  25, 122,  53,  16,  99,  88,  76,  65, 111,  22,  45,  15,
#        114,  39,  68,  23,   4,   9, 115,  46,  92,  21,  69,  91,   0,
#          6,  44,  61,  43,  90, 113,  12,  20,  38,  58,  13, 107,  35,
#          5,  67,  81,  59, 105, 104,  36,  82,  84, 112,  89,  41,  66,
#         18, 110,  64,  87,  11,   8,  10,   7])}, 127: {'train_cv_mean': np.float64(0.8383582265897953), 'train_cv_std': np.float64(0.00414873105298472), 'train_cv_scores': array([0.84422335, 0.83556073, 0.83529061]), 'val_roc_auc': np.float64(0.8282416674790918), 'feature_indices': array([ 32, 101, 124,  78,  55,   2,  75,  29,  98,  52, 121,  27,  31,
#         54, 119,  96,   1,  50,  73, 123,  77,  26, 100, 103, 118, 126,
#         34,  49,  80,  95,  57,  72,  33,  56,  79, 102, 125,   3,  14,
#         37,  47,  24, 106,  60,  97,  85,  74, 120,  28, 108,  93, 116,
#         51,  83,  17,  70,  40,  62,  86,  42, 109,  19, 117,  48,  63,
#         94,  30,  71,  25, 122,  53,  16,  99,  88,  76,  65, 111,  22,
#         45,  15, 114,  39,  68,  23,   4,   9, 115,  46,  92,  21,  69,
#         91,   0,   6,  44,  61,  43,  90, 113,  12,  20,  38,  58,  13,
#        107,  35,   5,  67,  81,  59, 105, 104,  36,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 129: {'train_cv_mean': np.float64(0.8383582265897953), 'train_cv_std': np.float64(0.00414873105298472), 'train_cv_scores': array([0.84422335, 0.83556073, 0.83529061]), 'val_roc_auc': np.float64(0.8282416674790918), 'feature_indices': array([ 32, 101, 124,  78,  55,   2,  75,  29,  98,  52, 121,  27,  31,
#         54, 119,  96,   1,  50,  73, 123,  77,  26, 100, 103, 118, 126,
#         34,  49,  80,  95,  57,  72,  33,  56,  79, 102, 125,   3,  14,
#         37,  47,  24, 106,  60,  97,  85,  74, 120,  28, 108,  93, 116,
#         51,  83,  17,  70,  40,  62,  86,  42, 109,  19, 117,  48,  63,
#         94,  30,  71,  25, 122,  53,  16,  99,  88,  76,  65, 111,  22,
#         45,  15, 114,  39,  68,  23,   4,   9, 115,  46,  92,  21,  69,
#         91,   0,   6,  44,  61,  43,  90, 113,  12,  20,  38,  58,  13,
#        107,  35,   5,  67,  81,  59, 105, 104,  36,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 131: {'train_cv_mean': np.float64(0.8383582265897953), 'train_cv_std': np.float64(0.00414873105298472), 'train_cv_scores': array([0.84422335, 0.83556073, 0.83529061]), 'val_roc_auc': np.float64(0.8282416674790918), 'feature_indices': array([ 32, 101, 124,  78,  55,   2,  75,  29,  98,  52, 121,  27,  31,
#         54, 119,  96,   1,  50,  73, 123,  77,  26, 100, 103, 118, 126,
#         34,  49,  80,  95,  57,  72,  33,  56,  79, 102, 125,   3,  14,
#         37,  47,  24, 106,  60,  97,  85,  74, 120,  28, 108,  93, 116,
#         51,  83,  17,  70,  40,  62,  86,  42, 109,  19, 117,  48,  63,
#         94,  30,  71,  25, 122,  53,  16,  99,  88,  76,  65, 111,  22,
#         45,  15, 114,  39,  68,  23,   4,   9, 115,  46,  92,  21,  69,
#         91,   0,   6,  44,  61,  43,  90, 113,  12,  20,  38,  58,  13,
#        107,  35,   5,  67,  81,  59, 105, 104,  36,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 133: {'train_cv_mean': np.float64(0.8383582265897953), 'train_cv_std': np.float64(0.00414873105298472), 'train_cv_scores': array([0.84422335, 0.83556073, 0.83529061]), 'val_roc_auc': np.float64(0.8282416674790918), 'feature_indices': array([ 32, 101, 124,  78,  55,   2,  75,  29,  98,  52, 121,  27,  31,
#         54, 119,  96,   1,  50,  73, 123,  77,  26, 100, 103, 118, 126,
#         34,  49,  80,  95,  57,  72,  33,  56,  79, 102, 125,   3,  14,
#         37,  47,  24, 106,  60,  97,  85,  74, 120,  28, 108,  93, 116,
#         51,  83,  17,  70,  40,  62,  86,  42, 109,  19, 117,  48,  63,
#         94,  30,  71,  25, 122,  53,  16,  99,  88,  76,  65, 111,  22,
#         45,  15, 114,  39,  68,  23,   4,   9, 115,  46,  92,  21,  69,
#         91,   0,   6,  44,  61,  43,  90, 113,  12,  20,  38,  58,  13,
#        107,  35,   5,  67,  81,  59, 105, 104,  36,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 135: {'train_cv_mean': np.float64(0.8383582265897953), 'train_cv_std': np.float64(0.00414873105298472), 'train_cv_scores': array([0.84422335, 0.83556073, 0.83529061]), 'val_roc_auc': np.float64(0.8282416674790918), 'feature_indices': array([ 32, 101, 124,  78,  55,   2,  75,  29,  98,  52, 121,  27,  31,
#         54, 119,  96,   1,  50,  73, 123,  77,  26, 100, 103, 118, 126,
#         34,  49,  80,  95,  57,  72,  33,  56,  79, 102, 125,   3,  14,
#         37,  47,  24, 106,  60,  97,  85,  74, 120,  28, 108,  93, 116,
#         51,  83,  17,  70,  40,  62,  86,  42, 109,  19, 117,  48,  63,
#         94,  30,  71,  25, 122,  53,  16,  99,  88,  76,  65, 111,  22,
#         45,  15, 114,  39,  68,  23,   4,   9, 115,  46,  92,  21,  69,
#         91,   0,   6,  44,  61,  43,  90, 113,  12,  20,  38,  58,  13,
#        107,  35,   5,  67,  81,  59, 105, 104,  36,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 137: {'train_cv_mean': np.float64(0.8383582265897953), 'train_cv_std': np.float64(0.00414873105298472), 'train_cv_scores': array([0.84422335, 0.83556073, 0.83529061]), 'val_roc_auc': np.float64(0.8282416674790918), 'feature_indices': array([ 32, 101, 124,  78,  55,   2,  75,  29,  98,  52, 121,  27,  31,
#         54, 119,  96,   1,  50,  73, 123,  77,  26, 100, 103, 118, 126,
#         34,  49,  80,  95,  57,  72,  33,  56,  79, 102, 125,   3,  14,
#         37,  47,  24, 106,  60,  97,  85,  74, 120,  28, 108,  93, 116,
#         51,  83,  17,  70,  40,  62,  86,  42, 109,  19, 117,  48,  63,
#         94,  30,  71,  25, 122,  53,  16,  99,  88,  76,  65, 111,  22,
#         45,  15, 114,  39,  68,  23,   4,   9, 115,  46,  92,  21,  69,
#         91,   0,   6,  44,  61,  43,  90, 113,  12,  20,  38,  58,  13,
#        107,  35,   5,  67,  81,  59, 105, 104,  36,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 139: {'train_cv_mean': np.float64(0.8383582265897953), 'train_cv_std': np.float64(0.00414873105298472), 'train_cv_scores': array([0.84422335, 0.83556073, 0.83529061]), 'val_roc_auc': np.float64(0.8282416674790918), 'feature_indices': array([ 32, 101, 124,  78,  55,   2,  75,  29,  98,  52, 121,  27,  31,
#         54, 119,  96,   1,  50,  73, 123,  77,  26, 100, 103, 118, 126,
#         34,  49,  80,  95,  57,  72,  33,  56,  79, 102, 125,   3,  14,
#         37,  47,  24, 106,  60,  97,  85,  74, 120,  28, 108,  93, 116,
#         51,  83,  17,  70,  40,  62,  86,  42, 109,  19, 117,  48,  63,
#         94,  30,  71,  25, 122,  53,  16,  99,  88,  76,  65, 111,  22,
#         45,  15, 114,  39,  68,  23,   4,   9, 115,  46,  92,  21,  69,
#         91,   0,   6,  44,  61,  43,  90, 113,  12,  20,  38,  58,  13,
#        107,  35,   5,  67,  81,  59, 105, 104,  36,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 141: {'train_cv_mean': np.float64(0.8383582265897953), 'train_cv_std': np.float64(0.00414873105298472), 'train_cv_scores': array([0.84422335, 0.83556073, 0.83529061]), 'val_roc_auc': np.float64(0.8282416674790918), 'feature_indices': array([ 32, 101, 124,  78,  55,   2,  75,  29,  98,  52, 121,  27,  31,
#         54, 119,  96,   1,  50,  73, 123,  77,  26, 100, 103, 118, 126,
#         34,  49,  80,  95,  57,  72,  33,  56,  79, 102, 125,   3,  14,
#         37,  47,  24, 106,  60,  97,  85,  74, 120,  28, 108,  93, 116,
#         51,  83,  17,  70,  40,  62,  86,  42, 109,  19, 117,  48,  63,
#         94,  30,  71,  25, 122,  53,  16,  99,  88,  76,  65, 111,  22,
#         45,  15, 114,  39,  68,  23,   4,   9, 115,  46,  92,  21,  69,
#         91,   0,   6,  44,  61,  43,  90, 113,  12,  20,  38,  58,  13,
#        107,  35,   5,  67,  81,  59, 105, 104,  36,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 143: {'train_cv_mean': np.float64(0.8383582265897953), 'train_cv_std': np.float64(0.00414873105298472), 'train_cv_scores': array([0.84422335, 0.83556073, 0.83529061]), 'val_roc_auc': np.float64(0.8282416674790918), 'feature_indices': array([ 32, 101, 124,  78,  55,   2,  75,  29,  98,  52, 121,  27,  31,
#         54, 119,  96,   1,  50,  73, 123,  77,  26, 100, 103, 118, 126,
#         34,  49,  80,  95,  57,  72,  33,  56,  79, 102, 125,   3,  14,
#         37,  47,  24, 106,  60,  97,  85,  74, 120,  28, 108,  93, 116,
#         51,  83,  17,  70,  40,  62,  86,  42, 109,  19, 117,  48,  63,
#         94,  30,  71,  25, 122,  53,  16,  99,  88,  76,  65, 111,  22,
#         45,  15, 114,  39,  68,  23,   4,   9, 115,  46,  92,  21,  69,
#         91,   0,   6,  44,  61,  43,  90, 113,  12,  20,  38,  58,  13,
#        107,  35,   5,  67,  81,  59, 105, 104,  36,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 145: {'train_cv_mean': np.float64(0.8383582265897953), 'train_cv_std': np.float64(0.00414873105298472), 'train_cv_scores': array([0.84422335, 0.83556073, 0.83529061]), 'val_roc_auc': np.float64(0.8282416674790918), 'feature_indices': array([ 32, 101, 124,  78,  55,   2,  75,  29,  98,  52, 121,  27,  31,
#         54, 119,  96,   1,  50,  73, 123,  77,  26, 100, 103, 118, 126,
#         34,  49,  80,  95,  57,  72,  33,  56,  79, 102, 125,   3,  14,
#         37,  47,  24, 106,  60,  97,  85,  74, 120,  28, 108,  93, 116,
#         51,  83,  17,  70,  40,  62,  86,  42, 109,  19, 117,  48,  63,
#         94,  30,  71,  25, 122,  53,  16,  99,  88,  76,  65, 111,  22,
#         45,  15, 114,  39,  68,  23,   4,   9, 115,  46,  92,  21,  69,
#         91,   0,   6,  44,  61,  43,  90, 113,  12,  20,  38,  58,  13,
#        107,  35,   5,  67,  81,  59, 105, 104,  36,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 147: {'train_cv_mean': np.float64(0.8383582265897953), 'train_cv_std': np.float64(0.00414873105298472), 'train_cv_scores': array([0.84422335, 0.83556073, 0.83529061]), 'val_roc_auc': np.float64(0.8282416674790918), 'feature_indices': array([ 32, 101, 124,  78,  55,   2,  75,  29,  98,  52, 121,  27,  31,
#         54, 119,  96,   1,  50,  73, 123,  77,  26, 100, 103, 118, 126,
#         34,  49,  80,  95,  57,  72,  33,  56,  79, 102, 125,   3,  14,
#         37,  47,  24, 106,  60,  97,  85,  74, 120,  28, 108,  93, 116,
#         51,  83,  17,  70,  40,  62,  86,  42, 109,  19, 117,  48,  63,
#         94,  30,  71,  25, 122,  53,  16,  99,  88,  76,  65, 111,  22,
#         45,  15, 114,  39,  68,  23,   4,   9, 115,  46,  92,  21,  69,
#         91,   0,   6,  44,  61,  43,  90, 113,  12,  20,  38,  58,  13,
#        107,  35,   5,  67,  81,  59, 105, 104,  36,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}, 149: {'train_cv_mean': np.float64(0.8383582265897953), 'train_cv_std': np.float64(0.00414873105298472), 'train_cv_scores': array([0.84422335, 0.83556073, 0.83529061]), 'val_roc_auc': np.float64(0.8282416674790918), 'feature_indices': array([ 32, 101, 124,  78,  55,   2,  75,  29,  98,  52, 121,  27,  31,
#         54, 119,  96,   1,  50,  73, 123,  77,  26, 100, 103, 118, 126,
#         34,  49,  80,  95,  57,  72,  33,  56,  79, 102, 125,   3,  14,
#         37,  47,  24, 106,  60,  97,  85,  74, 120,  28, 108,  93, 116,
#         51,  83,  17,  70,  40,  62,  86,  42, 109,  19, 117,  48,  63,
#         94,  30,  71,  25, 122,  53,  16,  99,  88,  76,  65, 111,  22,
#         45,  15, 114,  39,  68,  23,   4,   9, 115,  46,  92,  21,  69,
#         91,   0,   6,  44,  61,  43,  90, 113,  12,  20,  38,  58,  13,
#        107,  35,   5,  67,  81,  59, 105, 104,  36,  82,  84, 112,  89,
#         41,  66,  18, 110,  64,  87,  11,   8,  10,   7])}}}]}

# %%
print('Best_Scaler:', results['best_scaler_name'])
print('Best_Params:', results['best_params'])
print('Best_N_Features:', results['best_n_features'])
print('Val ROC AUC:', results['val_roc_auc'])
print('CV Score:', results['train_cv_score'])
cv_score = results['train_cv_score']
test_predictions = results['test_predictions']
# Out:
# Best_Scaler: RobustScaler
# Best_Params: {'solver': 'liblinear', 'penalty': 'l1', 'max_iter': 1000, 'class_weight': 'balanced', 'C': 0.1}
# Best_N_Features: 89
# Val ROC AUC: 0.8286702407299251
# CV Score: 0.8389293551874845

# %%
submission_array = np.vstack([test_data['ID'].values, test_predictions]).T
submission_df = pd.DataFrame(submission_array, columns=['ID', 'radiant_win']).reset_index(drop=True)
submission_df.to_csv(f'CV {cv_score}.csv', index=None)
